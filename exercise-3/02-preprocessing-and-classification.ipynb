# %% [markdown]
# # Preprocessing and Classification
# <ul><li>Preview</li>
# <li>Review</li>
# <li>Import Corpus</li>
# <li>Pre-Processing</li>
# <ul><li>Tokenise</li>
# <li>Stop Words</li>
# <li>Lemmatise</li>
# <li>Most Frequent Terms</li></ul>
# <li>Classification</li>
# <ul><li>Featurise</li>
# <li>Training</li>
# <li>Prediction</li>
# <li>Extra: Cross-Validation</li></ul>
# <li>Literary Distinction</li>
# </ul>

# %% [markdown]
# # 0. Preview
#
# Run the 3 cells below as a summary of the rest of the module. No need to understand everything yet, but just to show you how easy it is to create a machine learning model!

# %%
# install and download required packages and data
# !pip install nltk
import nltk
nltk.download(['punkt','wordnet', 'stopwords','omw-1.4'])
# Out:
# Requirement already satisfied: nltk in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (3.8.1)
# Requirement already satisfied: click in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in d:\software\anaconda\envs\tifa-seminar-practical\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# True

# %%
# Get texts of interest that belong to identifiably different categories
unladen_swallow = 'high air-speed velocity'
swallow_grasping_coconut = 'low air-speed velocity'

# Transform them into the format NLTK expects
unladen_features_tagged = ({'high':True, 'air-speed': True, 'velocity': True}, 'unladen')
coconut_features_tagged = ({'low':True, 'air-speed': True, 'velocity': True}, 'coconut')

# Train a classifier to learn distinguishing features
classifier = nltk.NaiveBayesClassifier.train([unladen_features_tagged, coconut_features_tagged])

# %%
# It's a simple question of weight ratios!
# A five ounce bird could not carry a one pound coconut. 

unknown_swallow = "high velocity"
unknown_features = { 'high': True, 'velocity':True}

classifier.classify(unknown_features)
# Out:
# 'unladen'

# %% [markdown]
# # 1. Review
#
# The cells below are a quick reminder of the previous module, plus some basic text manipulation methods:

# %%
# Read Renfrew and Bahn
rb_text = open('data/r_and_b_sample.txt',encoding="utf-8").read()

# %%
# Inspect the text
rb_text
# Out:
# 'Where?\nSurvey and Excavation of Sites\nand Features\nA major characteristic of archaeology is that it commonly\ndraws evidence from fieldwork, that is, from\nsurvey and excavation. Traditionally, fieldwork was seen\nalmost exclusively in terms of the discovery and uncovering\nof sites. Today, archaeologists are more aware of\nthe high cost and destructiveness of excavation, and so\nwhile sites and their excavation remain of paramount\nimportance, site surface survey and subsurface detection\nusing non-destructive remote sensing devices\nare now widely used. Indeed, some archaeological\nprojects may not include excavation at all, and instead\nfocus on various forms of survey. The use of non-invasive\nsurvey not only leaves the archaeology undisturbed but\nalso helps to answer new questions. For example, the\nstudy of entire landscapes by regional survey is now a\nmajor part of archaeological fieldwork.\nIn archaeological fieldwork, we may distinguish\nbetween the methods used in the discovery of archaeological\nsites and non-site features or artifact scatters,\nand those employed once those sites and features have\nbeen discovered, which include detailed survey and\nselective excavation at individual sites. It is important\nto note that new evidence can often come from new\nwork at sites already the subject of fieldwork, such as Ian\nHodder’s renewal and reappraisal of the excavations of\nthe Turkish tell site of Çatalhöyük (see box, pp. 44–45).\nMuch potentially rich and rewarding material also lies\nlocked away in museum and institution vaults, waiting\nto be analyzed by innovative modern techniques. Yet\nit remains true that the great majority of archaeological\nresearch is still dependent on the collection of new\nmaterial by fresh fieldwork.\nDiscovering Archaeological Sites\nand Features\nOne major task of the archaeologist is to find and record\nthe location of sites and features. In this section we will\nbe reviewing some of the principal techniques used in site\ndiscovery. But we should not forget that many monuments\nhave never been lost to posterity: the massive pyramids of\nEgypt, or those of Teotihuacán near modern Mexico City,\nhave always been known to succeeding generations, as has\nthe Great Wall of China or many of the buildings in the\nForum in Rome. Their exact function or purpose may indeed\nhave aroused controversy down the centuries, but their\npresence, the fact of their existence, was never in doubt.\nNor can one credit archaeologists with the discovery of\nall those sites that were once lost. A signiﬁcant number of\nsites known today were found by accident: the amazing\nterracotta army of China’s ﬁrst emperor was unearthed in\n1974 by farmers digging for a well; in France, the decorated\ncaves of Lascaux were stumbled upon in 1940 by teenagers,\nand the underwater entrance to those of Cosquer\nwas discovered by a deep-sea diver in 1985. Countless\nunderwater wrecks have been spotted first by ﬁshermen,\nsponge-gatherers, and sport-divers. Construction workers\nbuilding new roads, subways, dams, and ofﬁce blocks have\nmade their fair share of discoveries too for example, the\nTemplo Mayor (Great Temple) of the Aztecs in Mexico City\n(see box, pp. 570 71).\nNevertheless, it is archaeologists who have systematically\nattempted to record these sites, and it is archaeologists\nwho seek out the full range of sites and features, large or\nsmall, that make up the great diversity of past landscapes.\nHow do they achieve this?\nA practical distinction can be drawn between site discovery\nconducted at ground level (ground reconnaissance)\nand discovery from the air or from space (aerial survey),\nalthough any one ﬁeld project will usually employ both\ntypes of reconnaissance.\n\nGround Reconnaissance\nMethods for identifying individual sites include consultation\nof documentary sources and place-name evidence,\nbut primarily comprises actual fieldwork, whether the\nmonitoring ofbuilcling developers\' progress in ...

# %%
# Make the text lower case
rb_lower = rb_text.lower()

# %%
# Tokenise
from nltk import word_tokenize
rb_tokens = word_tokenize(rb_lower)

# %%
# Check out the tokens
rb_tokens
# Out:
# ['where',
#  '?',
#  'survey',
#  'and',
#  'excavation',
#  'of',
#  'sites',
#  'and',
#  'features',
#  'a',
#  'major',
#  'characteristic',
#  'of',
#  'archaeology',
#  'is',
#  'that',
#  'it',
#  'commonly',
#  'draws',
#  'evidence',
#  'from',
#  'fieldwork',
#  ',',
#  'that',
#  'is',
#  ',',
#  'from',
#  'survey',
#  'and',
#  'excavation',
#  '.',
#  'traditionally',
#  ',',
#  'fieldwork',
#  'was',
#  'seen',
#  'almost',
#  'exclusively',
#  'in',
#  'terms',
#  'of',
#  'the',
#  'discovery',
#  'and',
#  'uncovering',
#  'of',
#  'sites',
#  '.',
#  'today',
#  ',',
#  'archaeologists',
#  'are',
#  'more',
#  'aware',
#  'of',
#  'the',
#  'high',
#  'cost',
#  'and',
#  'destructiveness',
#  'of',
#  'excavation',
#  ',',
#  'and',
#  'so',
#  'while',
#  'sites',
#  'and',
#  'their',
#  'excavation',
#  'remain',
#  'of',
#  'paramount',
#  'importance',
#  ',',
#  'site',
#  'surface',
#  'survey',
#  'and',
#  'subsurface',
#  'detection',
#  'using',
#  'non-destructive',
#  'remote',
#  'sensing',
#  'devices',
#  'are',
#  'now',
#  'widely',
#  'used',
#  '.',
#  'indeed',
#  ',',
#  'some',
#  'archaeological',
#  'projects',
#  'may',
#  'not',
#  'include',
#  'excavation',
#  'at',
#  'all',
#  ',',
#  'and',
#  'instead',
#  'focus',
#  'on',
#  'various',
#  'forms',
#  'of',
#  'survey',
#  '.',
#  'the',
#  'use',
#  'of',
#  'non-invasive',
#  'survey',
#  'not',
#  'only',
#  'leaves',
#  'the',
#  'archaeology',
#  'undisturbed',
#  'but',
#  'also',
#  'helps',
#  'to',
#  'answer',
#  'new',
#  'questions',
#  '.',
#  'for',
#  'example',
#  ',',
#  'the',
#  'study',
#  'of',
#  'entire',
#  'landscapes',
#  'by',
#  'regional',
#  'survey',
#  'is',
#  'now',
#  'a',
#  'major',
#  'part',
#  'of',
#  'archaeological',
#  'fieldwork',
#  '.',
#  'in',
#  'archaeological',
#  'fieldwork',
#  ',',
#  'we',
#  'may',
#  'distinguish',
#  'between',
#  'the',
#  'methods',
#  'used',
#  'in',
#  'the',
#  'discovery',
#  'of',
#  'archaeological',
#  'sites',
#  'and',
#  'non-site',
#  'features',
#  'or',
#  'artifact',
#  'scatters',
#  ',',
#  'and',
#  'those',
#  'employed',
#  'once',
#  'those',
#  'sites',
#  'and',
#  'features',
#  'have',
#  'been',
#  'discovered',
#  ',',
#  'which',
#  'include',
#  'detailed',
#  'survey',
#  'and',
#  'selective',
#  'excavation',
#  'at',
#  'individual',
#  'sites',
#  '.',
#  'it',
#  'is',
#  'important',
#  'to',
#  'note',
#  'that',
#  'new',
#  'evidence',
#  'can',
#  'often',
#  'come',
#  'from',
#  'new',
#  'work',
#  'at',
#  'sites',
#  'already',
#  'the',
#  'subject',
#  'of',
#  'fieldwork',
#  ',',
#  'such',
#  'as',
#  'ian',
#  'hodder',
#  '’',
#  's',
#  'renewal',
#  'and',
#  'reappraisal',
#  'of',
#  'the',
#  'excavations',
#  'of',
#  'the',
#  'turkish',
#  'tell',
#  'site',
#  'of',
#  'çatalhöyük',
#  '(',
#  'see',
#  'box',
#  ',',
#  'pp',
#  '.',
#  '44–45',
#  ')',
#  '.',
#  'much',
#  'potentially',
#  'rich',
#  'and',
#  'rewarding',
#  'material',
#  'also',
#  'lies',
#  'locked',
#  'away',
#  'in',
#  'museum',
#  'and',
#  'institution',
#  'vaults',
#  ',',
#  'waiting',
#  'to',
#  'be',
#  'analyzed',
#  'by',
#  'innovative',
#  'modern',
#  'techniques',
#  '.',
#  'yet',
#  'it',
#  'remains',
#  'true',
#  'that',
#  'the',
#  'great',
#  'majority',
#  'of',
#  'archaeological',
#  'research',
#  'is',
#  'still',
#  'dependent',
#  'on',
#  'the',
#  'collection',
#  'of',
#  'new',
#  'material',
#  'by',
#  'fresh',
#  'fieldwork',
#  '.',
#  'discovering',
#  'archaeological',
#  'sites',
#  'and',
#  'features',
#  'one',
#  'major',
#  'task',
#  'of',
#  'the',
#  'archaeologist',
#  'is',
#  'to',
#  'find',
#  'and',
#  'record',
#  'the',
#  'location',
#  'of',
#  'sites',
#  'and',
#  'features',
#  '.',
#  'in',
#  'this',
#  'section',
#  'we',
#  'will',
#  'be',
#  'reviewing',
#  'some',
#  'of',
#  'the',
#  'principal',
#  'techniques',
#  'used',
#  'in',
#  'site',
#  'discovery',
#  '.',
#  'but',
#  'we',
#  'should',
#  'not',
#  'forget',
#  'that',
#  'many',
#  'monuments',
#  'have',
#  'never',
#  'been',
#  'lost',
#  'to',
#  'posterity',
#  ':',
#  'the',
#  'massive',
#  'pyramids',
#  'of',
#  'egypt',
#  ',',
#  'or',
#  'those',
#  'of',
#  'teotihuacán',
#  'near',
#  'modern',
#  'mexico',
#  'city',
#  ',',
#  'have',
#  'always',
#  'been',
#  'known',
#  'to',
#  'succeeding',
#  'generations',
#  ',',
#  'as',
#  'has',
#  'the',
#  'great',
#  'wall',
#  'of',
#  'china',
#  'or',
#  'many',
#  'of',
#  'the',
#  'buildings',
#  'in',
#  'the',
#  'forum',
#  'in',
#  'rome',
#  '.',
#  'their',
#  'exact',
#  'function',
#  'or',
#  'purpose',
#  'may',
#  'indeed',
#  'have',
#  'aroused',
#  'controversy',
#  'down',
#  'the',
#  'centuries',
#  ',',
#  'but',
#  'their',
#  'presence',
#  ',',
#  'the',
#  'fact',
#  'of',
#  'their',
#  'existence',
#  ',',
#  'was',
#  'never',
#  'in',
#  'doubt',
#  '.',
#  'nor',
#  'can',
#  'one',
#  'credit',
#  'archaeologists',
#  'with',
#  'the',
#  'discovery',
#  'of',
#  'all',
#  'those',
#  'sites',
#  'that',
#  'were',
#  'once',
#  'lost',
#  '.',
#  'a',
#  'signiﬁcant',
#  'number',
#  'of',
#  'sites',
#  'known',
#  'today',
#  'were',
#  'found',
#  'by',
#  'accident',
#  ':',
#  'the',
#  'amazing',
#  'terracotta',
#  'army',
#  'of',
#  'china',
#  '’',
#  's',
#  'ﬁrst',
#  'emperor',
#  'was',
#  'unearthed',
#  'in',
#  '1974',
#  'by',
#  'farmers',
#  'digging',
#  'for',
#  'a',
#  'well',
#  ';',
#  'in',
#  'france',
#  ',',
#  'the',
#  'decorated',
#  'caves',
#  'of',
#  'lascaux',
#  'were',
#  'stumbled',
#  'upon',
#  'in',
#  '1940',
#  'by',
#  'teenagers',
#  ',',
#  'and',
#  'the',
#  'underwater',
#  'entrance',
#  'to',
#  'those',
#  'of',
#  'cosquer',
#  'was',
#  'discovered',
#  'by',
#  'a',
#  'deep-sea',
#  'diver',
#  'in',
#  '1985.',
#  'countless',
#  'underwater',
#  'wrecks',
#  'have',
#  'been',
#  'spotted',
#  'first',
#  'by',
#  'ﬁshermen',
#  ',',
#  'sponge-gatherers',
#  ',',
#  'and',
#  'sport-divers',
#  '.',
#  'construction',
#  'workers',
#  'building',
#  'new',
#  'roads',
#  ',',
#  'subways',
#  ',',
#  'dams',
#  ',',
#  'and',
#  'ofﬁce',
#  'blocks',
#  'have',
#  'made',
#  'their',
#  'fair',
#  'share',
#  'of',
#  'discoveries',
#  'too',
#  'for',
#  'example',
#  ',',
#  'the',
#  'templo',
#  'mayor',
#  '(',
#  'great',
#  'temple',
#  ')',
#  'of',
#  'the',
#  'aztecs',
#  'in',
#  'mexico',
#  'city',
#  '(',
#  'see',
#  'box',
#  ',',
#  'pp',
#  '.',
#  '570',
#  '71',
#  ')',
#  '.',
#  'nevertheless',
#  ',',
#  'it',
#  'is',
#  'archaeologists',
#  'who',
#  'have',
#  'systematically',
#  'attempted',
#  'to',
#  'record',
#  'these',
#  'sites',
#  ',',
#  'and',
#  'it',
#  'is',
#  'archaeologists',
#  'who',
#  'seek',
#  'out',
#  'the',
#  'full',
#  'range',
#  'of',
#  'sites',
#  'and',
#  'features',
#  ',',
#  'large',
#  'or',
#  'small',
#  ',',
#  'that',
#  'make',
#  'up',
#  'the',
#  'great',
#  'diversity',
#  'of',
#  'past',
#  'landscapes',
#  '.',
#  'how',
#  'do',
#  'they',
#  'achieve',
#  'this',
#  '?',
#  'a',
#  'practical',
#  'distinction',
#  'can',
#  'be',
#  'drawn',
#  'between',
#  'site',
#  'discovery',
#  'conducted',
#  'at',
#  'ground',
#  'level',
#  '(',
#  'ground',
#  'reconnaissance',
#  ')',
#  'and',
#  'discovery',
#  'from',
#  'the',
#  'air',
#  'or',
#  'from',
#  'space',
#  '(',
#  'aerial',
#  'survey',
#  ')',
#  ',',
#  'although',
#  'any',
#  'one',
#  'ﬁeld',
#  'project',
#  'will',
#  'usually',
#  'employ',
#  'both',
#  'types',
#  'of',
#  'reconnaissance',
#  '.',
#  'ground',
#  'reconnaissance',
#  'methods',
#  'for',
#  'identifying',
#  'individual',
#  'sites',
#  'include',
#  'consultation',
#  'of',
#  'documentary',
#  'sources',
#  'and',
#  'place-name',
#  'evidence',
#  ',',
#  'but',
#  'primarily',
#  'comprises',
#  'actual',
#  'fieldwork',
#  ',',
#  'whether',
#  'the',
#  'monitoring',
#  'ofbuilcling',
#  'developers',
#  "'",
#  'progress',
#  'in',
#  'applied',
#  'or',
#  'compliance',
#  'archaeology',
#  '(',
#  'often',
#  'known',
#  'in',
#  'the',
#  'uk',
#  'as',
#  'salvage',
#  'or',
#  'rescue',
#  'archaeology',
#  ')',
#  ',',
#  'or',
#  'survey',
#  'in',
#  'circumstances',
#  'where',
#  'the',
#  'archaeologist',
#  'is',
#  'more',
#  'of',
#  'a',
#  'free',
#  'agent',
#  '.',
#  'documentary',
#  'sources',
#  '.',
#  'we',
#  'saw',
#  'how',
#  'schliemann',
#  "'s",
#  'firm',
#  'belief',
#  'in',
#  'the',
#  'historical',
#  'accuracy',
#  'of',
#  'the',
#  'writings',
#  'of',
#  'homer',
#  'led',
#  'directly',
#  'to',
#  'the',
#  'discovery',
#  'of',
#  'ancient',
#  'troy',
#  'in',
#  'chapter',
#  '1.',
#  'in',
#  'the',
#  '1960s',
#  ',',
#  'the',
#  'location',
#  'and',
#  'excavation',
#  'by',
#  'helge',
#  'and',
#  'anne',
#  'stine',
#  'ingstad',
#  'of',
#  'the',
#  'viking',
#  'settlement',
#  'of',
#  'lj\\nse',
#  'aux',
#  'meadows',
#  'in',
#  'newfoundland',
#  'was',
#  'similarly',
#  'due',
#  'in',
#  'large',
#  'part',
#  'to',
#  'clues',
#  'contained',
#  'in',
#  'medieval',
#  'viking',
#  'sagas',
#  '.',
#  'much',
#  'of',
#  'modern',
#  'biblical',
#  'an',
#  ':',
#  ':haeology',
#  'concerns',
#  'itself',
#  'with',
#  'the',
#  'search',
#  'in',
#  'the',
#  'near',
#  'east',
#  'for',
#  'evidence',
#  'of',
#  'the',
#  'places',
#  ',',
#  'people',
#  ',',
#  'and',
#  'events',
#  'described',
#  'in',
#  'the',
#  'old',
#  'and',
#  'new',
#  'testaments',
#  '.',
#  'treated',
#  'objectively',
#  'as',
#  'a',
#  'possible',
#  'source',
#  'of',
#  'information',
#  'about',
#  'near',
#  'eastern',
#  'sites',
#  ',',
#  'the',
#  'bible',
#  'can',
#  'indeed',
#  'be',
#  'a',
#  'rich',
#  'source',
#  'of',
#  'documentary',
#  'material',
#  ',',
#  'but',
#  'there',
#  'is',
#  'certainly',
#  'the',
#  'danger',
#  'that',
#  'belief',
#  'in',
#  'the',
#  'absolute',
#  'religious',
#  'truth',
#  'of',
#  'the',
#  'texts',
#  'can',
#  'cloud',
#  'an',
#  'impartial',
#  'assessment',
#  'of',
#  'their',
#  'archaeological',
#  'validity',
#  '.',
#  'much',
#  'research',
#  'in',
#  'biblical',
#  'archaeology',
#  'involves',
#  'attempting',
#  'to',
#  'link',
#  'named',
#  'biblical',
#  'sites',
#  'with',
#  'archaeologically',
#  'known',
#  'ones',
#  '.',
#  'place-name',
#  'evidence',
#  ',',
#  'however',
#  ',',
#  'can',
#  'also',
#  'lead',
#  'to',
#  'actual',
#  'discoveries',
#  'of',
#  'new',
#  'archaeological',
#  'sites',
#  '.',
#  'in',
#  'southwest',
#  'europe',
#  ',',
#  'for',
#  'example',
#  ',',
#  'many',
#  'prehistoric',
#  'stone',
#  'tombs',
#  'have',
#  'been',
#  'found',
#  'thanks',
#  'to',
#  'old',
#  'names',
#  'printed',
#  'on',
#  'maps',
#  'that',
#  'incorporate',
#  'local',
#  'words',
#  'for',
#  '``',
#  'stone',
#  "''",
#  'or',
#  '``',
#  'tomb',
#  '.',
#  "''",
#  'early',
#  'maps',
#  'and',
#  'old',
#  'street',
#  'names',
#  'are',
#  'even',
#  'more',
#  'important',
#  'in',
#  'helping',
#  'archaeologists',
#  'work',
#  'out',
#  'the',
#  'former',
#  'plans',
#  'of',
#  'historic',
#  'towns',
#  '.',
#  'in',
#  'england',
#  ',',
#  'it',
#  'is',
#  'possible',
#  'in',
#  'the',
#  'betterdocumented',
#  'medieval',
#  'towns',
#  'to',
#  'map',
#  'many',
#  'of',
#  'the',
#  'streets',
#  ',',
#  'houses',
#  ',',
#  'churches',
#  ',',
#  'and',
#  'castles',
#  'back',
#  'to',
#  'the',
#  'twelfth',
#  'century',
#  'cs',
#  ',',
#  'or',
#  'even',
#  'earlier',
#  ',',
#  'using',
#  'this',
#  'kind',
#  'of',
#  ...]

# %%
# Just how long is this text?
len(rb_tokens)
# Out:
# 12179

# %%
# Create a dictionary that counts token frequencies
from collections import Counter
rb_dict = Counter(rb_tokens)

# %%
# Dictionaries pair keys with values
rb_dict
# Out:
# Counter({'where': 19,
#          '?': 6,
#          'survey': 72,
#          'and': 358,
#          'excavation': 41,
#          'of': 455,
#          'sites': 65,
#          'features': 36,
#          'a': 231,
#          'major': 8,
#          'characteristic': 1,
#          'archaeology': 21,
#          'is': 114,
#          'that': 101,
#          'it': 63,
#          'commonly': 3,
#          'draws': 1,
#          'evidence': 11,
#          'from': 72,
#          'fieldwork': 8,
#          ',': 612,
#          '.': 425,
#          'traditionally': 3,
#          'was': 27,
#          'seen': 2,
#          'almost': 5,
#          'exclusively': 1,
#          'in': 271,
#          'terms': 2,
#          'the': 583,
#          'discovery': 10,
#          'uncovering': 3,
#          'today': 6,
#          'archaeologists': 26,
#          'are': 96,
#          'more': 27,
#          'aware': 1,
#          'high': 6,
#          'cost': 3,
#          'destructiveness': 1,
#          'so': 16,
#          'while': 6,
#          'their': 24,
#          'remain': 2,
#          'paramount': 1,
#          'importance': 4,
#          'site': 65,
#          'surface': 42,
#          'subsurface': 5,
#          'detection': 4,
#          'using': 14,
#          'non-destructive': 2,
#          'remote': 12,
#          'sensing': 13,
#          'devices': 5,
#          'now': 8,
#          'widely': 4,
#          'used': 39,
#          'indeed': 6,
#          'some': 30,
#          'archaeological': 53,
#          'projects': 8,
#          'may': 42,
#          'not': 29,
#          'include': 5,
#          'at': 40,
#          'all': 22,
#          'instead': 3,
#          'focus': 3,
#          'on': 51,
#          'various': 3,
#          'forms': 5,
#          'use': 14,
#          'non-invasive': 1,
#          'only': 22,
#          'leaves': 1,
#          'undisturbed': 6,
#          'but': 36,
#          'also': 30,
#          'helps': 1,
#          'to': 255,
#          'answer': 2,
#          'new': 16,
#          'questions': 3,
#          'for': 100,
#          'example': 24,
#          'study': 5,
#          'entire': 4,
#          'landscapes': 5,
#          'by': 79,
#          'regional': 5,
#          'part': 7,
#          'we': 12,
#          'distinguish': 1,
#          'between': 9,
#          'methods': 16,
#          'non-site': 1,
#          'or': 101,
#          'artifact': 5,
#          'scatters': 2,
#          'those': 17,
#          'employed': 8,
#          'once': 4,
#          'have': 56,
#          'been': 36,
#          'discovered': 12,
#          'which': 34,
#          'detailed': 3,
#          'selective': 2,
#          'individual': 9,
#          'important': 8,
#          'note': 3,
#          'can': 72,
#          'often': 20,
#          'come': 2,
#          'work': 16,
#          'already': 6,
#          'subject': 1,
#          'such': 46,
#          'as': 101,
#          'ian': 1,
#          'hodder': 1,
#          '’': 25,
#          's': 25,
#          'renewal': 1,
#          'reappraisal': 1,
#          'excavations': 3,
#          'turkish': 2,
#          'tell': 6,
#          'çatalhöyük': 1,
#          '(': 140,
#          'see': 37,
#          'box': 16,
#          'pp': 12,
#          '44–45': 1,
#          ')': 140,
#          'much': 10,
#          'potentially': 3,
#          'rich': 2,
#          'rewarding': 1,
#          'material': 14,
#          'lies': 4,
#          'locked': 1,
#          'away': 1,
#          'museum': 2,
#          'institution': 1,
#          'vaults': 1,
#          'waiting': 1,
#          'be': 108,
#          'analyzed': 3,
#          'innovative': 1,
#          'modern': 9,
#          'techniques': 13,
#          'yet': 2,
#          'remains': 13,
#          'true': 3,
#          'great': 16,
#          'majority': 1,
#          'research': 5,
#          'still': 3,
#          'dependent': 1,
#          'collection': 5,
#          'fresh': 1,
#          'discovering': 1,
#          'one': 31,
#          'task': 2,
#          'archaeologist': 13,
#          'find': 4,
#          'record': 11,
#          'location': 10,
#          'this': 42,
#          'section': 2,
#          'will': 20,
#          'reviewing': 1,
#          'principal': 1,
#          'should': 7,
#          'forget': 1,
#          'many': 20,
#          'monuments': 2,
#          'never': 3,
#          'lost': 3,
#          'posterity': 1,
#          ':': 18,
#          'massive': 1,
#          'pyramids': 2,
#          'egypt': 3,
#          'teotihuacán': 5,
#          'near': 9,
#          'mexico': 10,
#          'city': 10,
#          'always': 2,
#          'known': 16,
#          'succeeding': 1,
#          'generations': 1,
#          'has': 36,
#          'wall': 3,
#          'china': 3,
#          'buildings': 7,
#          'forum': 2,
#          'rome': 5,
#          'exact': 7,
#          'function': 4,
#          'purpose': 2,
#          'aroused': 1,
#          'controversy': 1,
#          'down': 3,
#          'centuries': 1,
#          'presence': 3,
#          'fact': 3,
#          'existence': 2,
#          'doubt': 1,
#          'nor': 1,
#          'credit': 1,
#          'with': 59,
#          'were': 22,
#          'signiﬁcant': 2,
#          'number': 9,
#          'found': 8,
#          'accident': 1,
#          'amazing': 1,
#          'terracotta': 2,
#          'army': 2,
#          'ﬁrst': 3,
#          'emperor': 2,
#          'unearthed': 2,
#          '1974': 1,
#          'farmers': 2,
#          'digging': 3,
#          'well': 11,
#          ';': 18,
#          'france': 1,
#          'decorated': 1,
#          'caves': 4,
#          'lascaux': 1,
#          'stumbled': 1,
#          'upon': 1,
#          '1940': 1,
#          'teenagers': 1,
#          'underwater': 8,
#          'entrance': 1,
#          'cosquer': 1,
#          'deep-sea': 2,
#          'diver': 1,
#          '1985.': 1,
#          'countless': 1,
#          'wrecks': 3,
#          'spotted': 1,
#          'first': 4,
#          'ﬁshermen': 1,
#          'sponge-gatherers': 1,
#          'sport-divers': 1,
#          'construction': 3,
#          'workers': 2,
#          'building': 3,
#          'roads': 4,
#          'subways': 2,
#          'dams': 1,
#          'ofﬁce': 1,
#          'blocks': 2,
#          'made': 6,
#          'fair': 1,
#          'share': 1,
#          'discoveries': 3,
#          'too': 5,
#          'templo': 1,
#          'mayor': 1,
#          'temple': 1,
#          'aztecs': 1,
#          '570': 1,
#          '71': 1,
#          'nevertheless': 4,
#          'who': 6,
#          'systematically': 3,
#          'attempted': 1,
#          'these': 32,
#          'seek': 2,
#          'out': 13,
#          'full': 2,
#          'range': 6,
#          'large': 18,
#          'small': 8,
#          'make': 7,
#          'up': 11,
#          'diversity': 1,
#          'past': 7,
#          'how': 10,
#          'do': 5,
#          'they': 30,
#          'achieve': 1,
#          'practical': 2,
#          'distinction': 2,
#          'drawn': 1,
#          'conducted': 2,
#          'ground': 22,
#          'level': 4,
#          'reconnaissance': 7,
#          'air': 9,
#          'space': 4,
#          'aerial': 27,
#          'although': 2,
#          'any': 11,
#          'ﬁeld': 12,
#          'project': 7,
#          'usually': 7,
#          'employ': 3,
#          'both': 12,
#          'types': 12,
#          'identifying': 2,
#          'consultation': 2,
#          'documentary': 4,
#          'sources': 4,
#          'place-name': 2,
#          'primarily': 1,
#          'comprises': 3,
#          'actual': 2,
#          'whether': 5,
#          'monitoring': 2,
#          'ofbuilcling': 1,
#          'developers': 2,
#          "'": 1,
#          'progress': 1,
#          'applied': 4,
#          'compliance': 3,
#          'uk': 1,
#          'salvage': 5,
#          'rescue': 3,
#          'circumstances': 1,
#          'free': 1,
#          'agent': 1,
#          'saw': 2,
#          'schliemann': 1,
#          "'s": 1,
#          'firm': 1,
#          'belief': 2,
#          'historical': 1,
#          'accuracy': 3,
#          'writings': 1,
#          'homer': 1,
#          'led': 3,
#          'directly': 2,
#          'ancient': 9,
#          'troy': 1,
#          'chapter': 9,
#          '1.': 1,
#          '1960s': 3,
#          'helge': 1,
#          'anne': 1,
#          'stine': 1,
#          'ingstad': 1,
#          'viking': 2,
#          'settlement': 5,
#          'lj\\nse': 1,
#          'aux': 1,
#          'meadows': 1,
#          'newfoundland': 1,
#          'similarly': 2,
#          'due': 2,
#          'clues': 1,
#          'contained': 2,
#          'medieval': 2,
#          'sagas': 1,
#          'biblical': 3,
#          'an': 53,
#          ':haeology': 1,
#          'concerns': 1,
#          'itself': 1,
#          'search': 5,
#          'east': 5,
#          'places': 1,
#          'people': 3,
#          'events': 1,
#          'described': 3,
#          'old': 4,
#          'testaments': 1,
#          'treated': 1,
#          'objectively': 1,
#          'possible': 8,
#          'source': 3,
#          'information': 22,
#          'about': 14,
#          'eastern': 3,
#          'bible': 1,
#          'there': 14,
#          'certainly': 1,
#          'danger': 1,
#          'absolute': 1,
#          'religious': 1,
#          'truth': 1,
#          'texts': 1,
#          'cloud': 5,
#          'impartial': 1,
#          'assessment': 3,
#          'validity': 1,
#          'involves': 4,
#          'attempting': 1,
#          'link': 2,
#          'named': 1,
#          'archaeologically': 1,
#          'ones': 2,
#          'however': 13,
#          'lead': 1,
#          'southwest': 1,
#          'europe': 3,
#          'prehistoric': 6,
#          'stone': 8,
#          'tombs': 7,
#          'thanks': 2,
#          'names': 3,
#          'printed': 1,
#          'maps': 17,
#          'incorporate': 2,
#          'local': 3,
#          'words': 1,
#          '``': 32,
#          "''": 44,
#          'tomb': 2,
#          'early': 4,
#          'street': 1,
#          'even': 10,
#          'helping': 2,
#          'former': 3,
#          'plans': 5,
#          'historic': 2,
#          'towns': 2,
#          'england': 6,
#          'betterdocumented': 1,
#          'map': 10,
#          'streets': 1,
#          'houses': 1,
#          'churches': 1,
#          'castles': 1,
#          'back': 2,
#          'twelfth': 1,
#          'century': 3,
#          'cs': 1,
#          'earlier': 3,
#          'kind': 6,
#          'then': 9,
#          'form': 7,
#          'reliable': 2,
#          'basis': 4,
#          'decide': 3,
#          'would': 5,
#          'most': 26,
#          'profitable': 1,
#          'carry': 3,
#          'cultural': 7,
#          'resource': 4,
#          'manageme': 1,
#          'nt': 1,
#          'specialized': 2,
#          'discussed': 3,
#          '15': 3,
#          'role': 2,
#          'locate': 6,
#          'before': 3,
#          'destroyed': 2,
#          'darns': 1,
#          'peatcutting': 1,
#          'drainage': 1,
#          'wetlands': 1,
#          'usa': 3,
#          'located': 5,
#          'recorded': 8,
#          'inventories': 1,
#          'every': 7,
#          'year': 4,
#          'under': 3,
#          'management': 5,
#          'crm': 2,
#          'laws': 2,
#          'considerably': 1,
#          'broadened': 1,
#          'strengthened': 1,
#          '1970s': 2,
#          'proper': 2,
#          'liaison': 1,
#          'developer': 1,
#          'allow': 2,
#          'take': 5,
#          'place': 7,
#          'advance': 3,
#          'along': 8,
#          'projected': 1,
#          'line': 3,
#          'road': 2,
#          'path': 1,
#          'development': 5,
#          'thus': 3,
#          'require': 2,
#          'cases': 3,
#          'cause': 1,
#          'altered': 1,
#          'certain': 2,
#          'during': 6,
#          'incorporated': 2,
#          'into': 28,
#          'station': 2,
#          'architecture': 1,
#          'britain': 6,
#          'surveys': 6,
#          'undertaken': 5,
#          'context': 9,
#          'influence': 1,
#          'british': 6,
#          'national': 3,
#          'planning': 3,
#          'policy': 1,
#          'framework': 1,
#          'meant': 1,
#          'expenditure': 1,
#          'grown': 1,
#          'than': 20,
#          '£10': 1,
#          'million': 2,
#          '$': 1,
#          '15.4': 1,
#          'annually': 1,
#          'does': 3,
#          'set': 2,
#          'locating': 3,
#          'other': 26,
#          'through': 19,
#          'conventional': 5,
#          'valid': 1,
#          'method': 18,
#          'look': 3,
#          'prominent': 1,
#          'landscape': 14,
#          'particularly': 10,
#          'surviving': 3,
#          'remnants': 1,
#          'walled': 1,
#          'burial': 3,
#          'mounds': 1,
#          'north': 5,
#          'america': 3,
#          'wessex': 1,
#          'southern': 3,
#          'visible': 6,
#          'scatter': 1,
#          'artifacts': 17,
#          'thorough': 1,
#          'what': 10,
#          'call': 2,
#          'detected': 5,
#          'recent': 4,
#          'years': 4,
#          'become': 6,
#          'interested': 2,
#          'reconstructing': 1,
#          'human': 6,
#          'begun': 2,
#          'realize': 1,
#          'very': 8,
#          'faint': 1,
#          'might': 4,
#          'qualify': 1,
#          'represent': 2,
#          'activity': 2,
#          'scholars': 3,
#          'suggested': 1,
#          'off-site': 2,
#          'nonsite': 1,
#          'areas': 24,
#          'low': 3,
#          'density': 1,
#          'done': 3,
#          'systematic': 2,
#          'involving': 3,
#          'careful': 1,
#          'sampling': 5,
#          'procedures': 3,
#          'below': 7,
#          'approach': 4,
#          'useful': 9,
#          'leading': 1,
#          'mobile': 5,
#          'way': 8,
#          'life': 2,
#          'left': 6,
#          'sparse': 1,
#          'africa': 5,
#          'further': 5,
#          'discussion': 2,
#          '5': 6,
#          'another': 7,
#          'reason': 1,
#          'growth': 1,
#          'studies': 2,
#          'pioneering': 1,
#          'researches': 1,
#          'gordon': 1,
#          'willey': 1,
#          'virú': 1,
#          'valley': 5,
#          'peru': 1,
#          'william': 1,
#          't.': 1,
#          'sanders': 1,
#          '1926': 1,
#          '2008': 3,
#          'increasingly': 3,
#          'patterns': 5,
#          'distribution': 7,
#          'across': 8,
#          'within': 10,
#          'given': 4,
#          'region': 3,
#          'signiﬁcance': 2,
#          'understanding': 4,
#          'societies': 1,
#          '5.': 1,
#          'here': 4,
#          'its': 15,
#          'impact': 1,
#          'ﬁeldwork': 3,
#          'rarely': 1,
#          'enough': 2,
#          'merely': 3,
#          'and/or': 1,
#          'excavate': 5,
#          'isolation': 1,
#          'whole': 4,
#          'regions': 3,
#          'need': 6,
#          'explored': 1,
#          'program': 1,
#          'last': 1,
#          'few': 3,
#          'decades': 3,
#          'developed': 7,
#          'being': 9,
#          'simply': 6,
#          'preliminary': 2,
#          'stage': 3,
#          'looking': 1,
#          'appropriate': 3,
#          'less': 4,
#          'independent': 1,
#          'inquiry': 1,
#          'area': 26,
#          'own': 1,
#          'right': 6,
#          'produce': 9,
#          'quite': 1,
#          'different': 19,
#          'achieved': 1,
#          'perhaps': 2,
#          'because': 4,
#          'permission': 1,
#          'dig': 3,
#          'forthcoming': 1,
#          'lack': 1,
#          'time': 16,
#          'funds': 4,
#          'slow': 2,
#          'costly': 2,
#          'whereas': 4,
#          'cheap': 1,
#          'quick': 2,
#          'relatively': 2,
#          'nondestructive': 1,
#          'requires': 1,
#          'gps': 2,
#          'compasses': 1,
#          'tapes': 1,
#          'deliberately': 1,
#          'choose': 1,
#          'data': 28,
#          'order': 4,
#          'investigate': 2,
#          'speciﬁc': 2,
#          'interest': 2,
#          'them': 12,
#          'could': 8,
#          'encompasses': 1,
#          'broad': 4,
#          'no': 4,
#          'longer': 2,
#          'just': 5,
#          'identiﬁcation': 1,
#          'recording': 20,
#          'sometimes': 4,
#          'natural': 7,
#          'mineral': 1,
#          'resources': 5,
#          'clay': 6,
#          'aimed': 1,
#          'studying': 3,
#          'spatial': 5,
#          'activities': 7,
#          'variations': 1,
#          'changes': 7,
#          'population': 1,
#          'relationships': 4,
#          'land': 3,
#          'practice': 2,
#          'formulated': 1,
#          'necessary': 3,
#          'collect': 1,
#          'corresponding': 2,
#          'scale': 6,
#          'provides': 2,
#          'least': 2,
#          'effort': 2,
#          'surveyed': 5,
#          'needs': 2,
#          'deﬁned': 2,
#          'boundaries': 2,
#          'extent': 7,
#          'style': 1,
#          'purely': 1,
#          'arbitrary': 1,
#          'though': 2,
#          'easiest': 1,
#          'establish': 1,
#          'history': 4,
#          'examined': 6,
#          'familiarize': 1,
#          'oneself': 1,
#          'previous': 1,
#          'materials': 3,
#          'assess': 2,
#          'covered': 1,
#          'removed': 4,
#          'processes': 4,
#          'little': 3,
#          'point': 9,
#          'searching': 1,
#          'sediments': 3,
#          'recently': 3,
#          'laid': 3,
#          'river': 2,
#          'action': 1,
#          'factors': 4,
#          'affected': 1,
#          'animal': 2,
#          'herds': 1,
#          'burrowing': 1,
#          'animals': 1,
#          'disturbed': 5,
#          'able': 8,
#          'examine': 3,
#          'geologists': 1,
#          'environmental': 3,
#          'specialists': 2,
#          'generally': 4,
#          'provide': 5,
#          'advice': 1,
#          'background': 1,
#          'help': 7,
#          'determine': 2,
#          'intensity': 3,
#          'coverage': 4,
#          'consideration': 1,
#          'available': 4,
#          'easy': 2,
#          'actually': 2,
#          'reach': 2,
#          'arid': 1,
#          'semi-arid': 1,
#          'environments': 1,
#          'vegetation': 6,
#          'among': 3,
#          'best': 2,
#          'type': 7,
#          'equatorial': 1,
#          'rainforest': 2,
#          'limited': 1,
#          'soil': 18,
#          'exposures': 1,
#          'banks': 1,
#          'unless': 2,
#          'labor': 1,
#          'permit': 1,
#          'cutting': 2,
#          'trails': 1,
#          'grid': 14,
#          'course': 3,
#          'contain': 7,
#          'variety': 2,
#          'single': 5,
#          'strategy': 2,
#          'inadequate': 1,
#          'cover': 7,
#          'flexibility': 1,
#          'required': 3,
#          'stratiﬁed': 1,
#          'zones': 2,
#          'differing': 1,
#          'visibility': 3,
#          'technique': 8,
#          'devised': 1,
#          'each': 17,
#          'moreover': 1,
#          'must': 5,
#          'remembered': 1,
#          'phases': 1,
#          'diagnostic': 2,
#          'others': 3,
#          'hunter-gatherer': 1,
#          'pastoral': 1,
#          'communities': 2,
#          'leave': 1,
#          'sparser': 1,
#          'imprint': 1,
#          'agricultural': 2,
#          'urban': 6,
#          'taken': 14,
#          'account': 2,
#          'when': 6,
#          'recovery': 1,
#          'consider': 1,
#          'collected': 6,
#          'associations': 1,
#          'parts': 10,
#          'mentioned': 2,
#          'above': 2,
#          'sensible': 1,
#          'option': 1,
#          'total': 5,
#          'partial': 1,
#          'p.': 12,
#          '80': 2,
#          'two': 13,
#          'basic': 3,
#          'kinds': 4,
#          'unsystematic': 1,
#          'simpler': 1,
#          'walking': 1,
#          'scanning': 2,
#          'strip': 1,
#          'collecting': 3,
#          'examining': 2,
#          'together': 1,
#          'felt': 1,
#          'results': 6,
#          'biased': 1,
#          'misleading': 1,
#          'walkers': 1,
#          'inherent': 1,
#          'desire': 1,
#          'ﬁnd': 2,
#          'therefore': 9,
#          'tend': 1,
#          'concentrate': 1,
#          'seem': 1,
#          'richer': 1,
#          'rather': 5,
#          'obtaining': 1,
#          'sample': 3,
#          'representative': 2,
#          'enable': 4,
#          'varying': 2,
#          'periods': 2,
#          'hand': 2,
#          'ﬂexible': 1,
#          'enabling': 1,
#          'team': 6,
#          'greater': 4,
#          'efforts': 1,
#          'proved': 5,
#          'likely': 3,
#          'ﬁnds': 3,
#          'employing': 1,
#          'either': 5,
#          'system': 4,
#          'series': 6,
#          'equally': 2,
#          'spaced': 2,
#          'traverses': 1,
#          'transects': 1,
#          'straight': 1,
#          'paths': 1,
#          'searched': 1,
#          'divided': 2,
#          'sectors': 1,
#          'walked': 1,
#          'under-': 1,
#          'overrepresented': 1,
#          'communication': 1,
#          'revealed': 6,
#          'watercourses': 1,
#          'canals': 3,
#          'probable': 1,
#          'cultivation': 2,
#          'alternatively': 1,
#          'intensive': 2,
#          'aiming': 1,
#          'sitecluster': 1,
#          'micro-regional': 1,
#          'paradox': 1,
#          'world': 4,
#          'greatest': 1,
#          'famous': 3,
#          'studied': 2,
#          'since': 7,
#          'attention': 1,
#          'focused': 1,
#          'grandiose': 2,
#          'themselves': 3,
#          'attempt': 2,
#          'mapping': 19,
#          'initiated': 1,
#          'added': 4,
#          'hugely': 1,
#          'our': 1,
#          'knowledge': 2,
#          'around': 4,
#          'pyramidtemples': 1,
#          '97': 2,
#          '100': 2,
#          'vital': 2,
#          'continues': 2,
#          'grow': 1,
#          'supplemented': 1,
#          'preceded': 1,
#          'availability': 1,
#          'images': 36,
#          'factor': 1,
#          'selecting': 1,
#          'delineating': 1,
#          'satellite': 10,
#          'airborne': 3,
#          'spaceborne': 1,
#          'component': 1,
#          'acquiring': 1,
#          'photographs': 10,
#          'aircraft': 7,
#          'satellites': 3,
#          'uavs': 1,
#          'drones': 1,
#          'analysis': 11,
#          'interpreted': 3,
#          'integrated': 3,
#          'ground-based': 2,
#          'documents': 1,
#          'viewpoint': 1,
#          'photo': 1,
#          'interpreter': 3,
#          'image': 7,
#          'analyst': 1,
#          'multispectral/': 1,
#          'hyperspectral': 1,
#          'traditional': 2,
#          'differ': 1,
#          'resolution': 4,
#          'issues': 1,
#          'interpretation': 4,
#          'collectively': 1,
#          'referred': 1,
#          'millions': 2,
#          'specialist': 1,
#          'libraries': 1,
#          'lesser': 1,
#          'quantity': 1,
#          'freely': 1,
#          'online': 1,
#          'result': 5,
#          'overlapping': 3,
#          'predeﬁned': 1,
#          'conducting': 1,
#          'prospective': 2,
#          'light': 5,
#          'stressed': 1,
#          'wide': 5,
#          'purposes': 3,
#          'photographing': 1,
#          'anything': 1,
#          'tomorrow': 1,
#          'taking': 3,
#          'tally': 1,
#          'grows': 1,
#          'tools': 3,
#          'means': 5,
#          'end': 2,
#          'reveal': 5,
#          'taker': 1,
#          'examination': 2,
#          'terrain': 7,
#          'pictures': 2,
#          'skills': 1,
#          'experience': 1,
#          'keen': 1,
#          'eye': 1,
#          'needed': 4,
#          'differentiate': 1,
#          'traces': 1,
#          'vehicle': 2,
#          'tracks': 1,
#          'riverbeds': 1,
#          'produced': 3,
#          'process': 2,
#          'benefits': 1,
#          'including': 6,
#          'awareness': 1,
#          'contemporary': 3,
#          'oblique': 4,
#          'vertical': 16,
#          ...})

# %%
# Report the ten most common tokens in the novel
rb_dict.most_common(10)
# Out:
# [(',', 612),
#  ('the', 583),
#  ('of', 455),
#  ('.', 425),
#  ('and', 358),
#  ('in', 271),
#  ('to', 255),
#  ('a', 231),
#  ('(', 140),
#  (')', 140)]

# %%
# Get the frequency of a specific word
rb_dict['archaeology']
# Out:
# 21

# %% [markdown]
# # 2. Import Corpus

# %% [markdown]
# ## Operating System Interface!
#
# Up to this point, we have only worked with one text at a time. It is simple enough to read in a single plaintext file, but we often find ourselves with many files residing in a folder on our hard drive. In order to access these, we will have to instruct Python to navigate our computer and access the files sequentially.
#
# Even though it sounds simple, this is the moment your computer ceases to be an appliance and transforms into a tool. The <i>os</i> package allows Python to speak with the rest of your computer's systems and file storage. You now have access to any file on your computer and can manipulate them using the code you have learned so far. With great power comes great responsibility!
#
# For now, we will look at just one function from <i>os</i> that will return a list of the files in a given directory.

# %%
import os

# %%
# Report the files in the current folder
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01-sequence-labeling.ipynb',
#  '02-preprocessing-and-classification.ipynb',
#  'data']

# %%
# Follow one of the reported folders
os.listdir('data/movie_reviews')
# Out:
# ['ebert', 'negative', 'positive']

# %%
# And follow deeper
os.listdir('data/movie_reviews/negative')
# Out:
# ['cv000_29416.txt',
#  'cv001_19502.txt',
#  'cv002_17424.txt',
#  'cv003_12683.txt',
#  'cv004_12641.txt',
#  'cv005_29357.txt',
#  'cv006_17022.txt',
#  'cv007_4992.txt',
#  'cv008_29326.txt',
#  'cv009_29417.txt',
#  'cv010_29063.txt',
#  'cv011_13044.txt',
#  'cv012_29411.txt',
#  'cv013_10494.txt',
#  'cv014_15600.txt',
#  'cv015_29356.txt',
#  'cv016_4348.txt',
#  'cv017_23487.txt',
#  'cv018_21672.txt',
#  'cv019_16117.txt',
#  'cv020_9234.txt',
#  'cv021_17313.txt',
#  'cv022_14227.txt',
#  'cv023_13847.txt',
#  'cv024_7033.txt',
#  'cv025_29825.txt',
#  'cv026_29229.txt',
#  'cv027_26270.txt',
#  'cv028_26964.txt',
#  'cv029_19943.txt',
#  'cv030_22893.txt',
#  'cv031_19540.txt',
#  'cv032_23718.txt',
#  'cv033_25680.txt',
#  'cv034_29446.txt',
#  'cv035_3343.txt',
#  'cv036_18385.txt',
#  'cv037_19798.txt',
#  'cv038_9781.txt',
#  'cv039_5963.txt',
#  'cv040_8829.txt',
#  'cv041_22364.txt',
#  'cv042_11927.txt',
#  'cv043_16808.txt',
#  'cv044_18429.txt',
#  'cv045_25077.txt',
#  'cv046_10613.txt',
#  'cv047_18725.txt',
#  'cv048_18380.txt',
#  'cv049_21917.txt',
#  'cv050_12128.txt',
#  'cv051_10751.txt',
#  'cv052_29318.txt',
#  'cv053_23117.txt',
#  'cv054_4101.txt',
#  'cv055_8926.txt',
#  'cv056_14663.txt',
#  'cv057_7962.txt',
#  'cv058_8469.txt',
#  'cv059_28723.txt',
#  'cv060_11754.txt',
#  'cv061_9321.txt',
#  'cv062_24556.txt',
#  'cv063_28852.txt',
#  'cv064_25842.txt',
#  'cv065_16909.txt',
#  'cv066_11668.txt',
#  'cv067_21192.txt',
#  'cv068_14810.txt',
#  'cv069_11613.txt',
#  'cv070_13249.txt',
#  'cv071_12969.txt',
#  'cv072_5928.txt',
#  'cv073_23039.txt',
#  'cv074_7188.txt',
#  'cv075_6250.txt',
#  'cv076_26009.txt',
#  'cv077_23172.txt',
#  'cv078_16506.txt',
#  'cv079_12766.txt',
#  'cv080_14899.txt',
#  'cv081_18241.txt',
#  'cv082_11979.txt',
#  'cv083_25491.txt',
#  'cv084_15183.txt',
#  'cv085_15286.txt',
#  'cv086_19488.txt',
#  'cv087_2145.txt',
#  'cv088_25274.txt',
#  'cv089_12222.txt',
#  'cv090_0049.txt',
#  'cv091_7899.txt',
#  'cv092_27987.txt',
#  'cv093_15606.txt',
#  'cv094_27868.txt',
#  'cv095_28730.txt',
#  'cv096_12262.txt',
#  'cv097_26081.txt',
#  'cv098_17021.txt',
#  'cv099_11189.txt',
#  'cv100_12406.txt',
#  'cv101_10537.txt',
#  'cv102_8306.txt',
#  'cv103_11943.txt',
#  'cv104_19176.txt',
#  'cv105_19135.txt',
#  'cv106_18379.txt',
#  'cv107_25639.txt',
#  'cv108_17064.txt',
#  'cv109_22599.txt',
#  'cv110_27832.txt',
#  'cv111_12253.txt',
#  'cv112_12178.txt',
#  'cv113_24354.txt',
#  'cv114_19501.txt',
#  'cv115_26443.txt',
#  'cv116_28734.txt',
#  'cv117_25625.txt',
#  'cv118_28837.txt',
#  'cv119_9909.txt',
#  'cv120_3793.txt',
#  'cv121_18621.txt',
#  'cv122_7891.txt',
#  'cv123_12165.txt',
#  'cv124_3903.txt',
#  'cv125_9636.txt',
#  'cv126_28821.txt',
#  'cv127_16451.txt',
#  'cv128_29444.txt',
#  'cv129_18373.txt',
#  'cv130_18521.txt',
#  'cv131_11568.txt',
#  'cv132_5423.txt',
#  'cv133_18065.txt',
#  'cv134_23300.txt',
#  'cv135_12506.txt',
#  'cv136_12384.txt',
#  'cv137_17020.txt',
#  'cv138_13903.txt',
#  'cv139_14236.txt',
#  'cv140_7963.txt',
#  'cv141_17179.txt',
#  'cv142_23657.txt',
#  'cv143_21158.txt',
#  'cv144_5010.txt',
#  'cv145_12239.txt',
#  'cv146_19587.txt',
#  'cv147_22625.txt',
#  'cv148_18084.txt',
#  'cv149_17084.txt',
#  'cv150_14279.txt',
#  'cv151_17231.txt',
#  'cv152_9052.txt',
#  'cv153_11607.txt',
#  'cv154_9562.txt',
#  'cv155_7845.txt',
#  'cv156_11119.txt',
#  'cv157_29302.txt',
#  'cv158_10914.txt',
#  'cv159_29374.txt',
#  'cv160_10848.txt',
#  'cv161_12224.txt',
#  'cv162_10977.txt',
#  'cv163_10110.txt',
#  'cv164_23451.txt',
#  'cv165_2389.txt',
#  'cv166_11959.txt',
#  'cv167_18094.txt',
#  'cv168_7435.txt',
#  'cv169_24973.txt',
#  'cv170_29808.txt',
#  'cv171_15164.txt',
#  'cv172_12037.txt',
#  'cv173_4295.txt',
#  'cv174_9735.txt',
#  'cv175_7375.txt',
#  'cv176_14196.txt',
#  'cv177_10904.txt',
#  'cv178_14380.txt',
#  'cv179_9533.txt',
#  'cv180_17823.txt',
#  'cv181_16083.txt',
#  'cv182_7791.txt',
#  'cv183_19826.txt',
#  'cv184_26935.txt',
#  'cv185_28372.txt',
#  'cv186_2396.txt',
#  'cv187_14112.txt',
#  'cv188_20687.txt',
#  'cv189_24248.txt',
#  'cv190_27176.txt',
#  'cv191_29539.txt',
#  'cv192_16079.txt',
#  'cv193_5393.txt',
#  'cv194_12855.txt',
#  'cv195_16146.txt',
#  'cv196_28898.txt',
#  'cv197_29271.txt',
#  'cv198_19313.txt',
#  'cv199_9721.txt',
#  'cv200_29006.txt',
#  'cv201_7421.txt',
#  'cv202_11382.txt',
#  'cv203_19052.txt',
#  'cv204_8930.txt',
#  'cv205_9676.txt',
#  'cv206_15893.txt',
#  'cv207_29141.txt',
#  'cv208_9475.txt',
#  'cv209_28973.txt',
#  'cv210_9557.txt',
#  'cv211_9955.txt',
#  'cv212_10054.txt',
#  'cv213_20300.txt',
#  'cv214_13285.txt',
#  'cv215_23246.txt',
#  'cv216_20165.txt',
#  'cv217_28707.txt',
#  'cv218_25651.txt',
#  'cv219_19874.txt',
#  'cv220_28906.txt',
#  'cv221_27081.txt',
#  'cv222_18720.txt',
#  'cv223_28923.txt',
#  'cv224_18875.txt',
#  'cv225_29083.txt',
#  'cv226_26692.txt',
#  'cv227_25406.txt',
#  'cv228_5644.txt',
#  'cv229_15200.txt',
#  'cv230_7913.txt',
#  'cv231_11028.txt',
#  'cv232_16768.txt',
#  'cv233_17614.txt',
#  'cv234_22123.txt',
#  'cv235_10704.txt',
#  'cv236_12427.txt',
#  'cv237_20635.txt',
#  'cv238_14285.txt',
#  'cv239_29828.txt',
#  'cv240_15948.txt',
#  'cv241_24602.txt',
#  'cv242_11354.txt',
#  'cv243_22164.txt',
#  'cv244_22935.txt',
#  'cv245_8938.txt',
#  'cv246_28668.txt',
#  'cv247_14668.txt',
#  'cv248_15672.txt',
#  'cv249_12674.txt',
#  'cv250_26462.txt',
#  'cv251_23901.txt',
#  'cv252_24974.txt',
#  'cv253_10190.txt',
#  'cv254_5870.txt',
#  'cv255_15267.txt',
#  'cv256_16529.txt',
#  'cv257_11856.txt',
#  'cv258_5627.txt',
#  'cv259_11827.txt',
#  'cv260_15652.txt',
#  'cv261_11855.txt',
#  'cv262_13812.txt',
#  'cv263_20693.txt',
#  'cv264_14108.txt',
#  'cv265_11625.txt',
#  'cv266_26644.txt',
#  'cv267_16618.txt',
#  'cv268_20288.txt',
#  'cv269_23018.txt',
#  'cv270_5873.txt',
#  'cv271_15364.txt',
#  'cv272_20313.txt',
#  'cv273_28961.txt',
#  'cv274_26379.txt',
#  'cv275_28725.txt',
#  'cv276_17126.txt',
#  'cv277_20467.txt',
#  'cv278_14533.txt',
#  'cv279_19452.txt',
#  'cv280_8651.txt',
#  'cv281_24711.txt',
#  'cv282_6833.txt',
#  'cv283_11963.txt',
#  'cv284_20530.txt',
#  'cv285_18186.txt',
#  'cv286_26156.txt',
#  'cv287_17410.txt',
#  'cv288_20212.txt',
#  'cv289_6239.txt',
#  'cv290_11981.txt',
#  'cv291_26844.txt',
#  'cv292_7804.txt',
#  'cv293_29731.txt',
#  'cv294_12695.txt',
#  'cv295_17060.txt',
#  'cv296_13146.txt',
#  'cv297_10104.txt',
#  'cv298_24487.txt',
#  'cv299_17950.txt',
#  'cv300_23302.txt',
#  'cv301_13010.txt',
#  'cv302_26481.txt',
#  'cv303_27366.txt',
#  'cv304_28489.txt',
#  'cv305_9937.txt',
#  'cv306_10859.txt',
#  'cv307_26382.txt',
#  'cv308_5079.txt',
#  'cv309_23737.txt',
#  'cv310_14568.txt',
#  'cv311_17708.txt',
#  'cv312_29308.txt',
#  'cv313_19337.txt',
#  'cv314_16095.txt',
#  'cv315_12638.txt',
#  'cv316_5972.txt',
#  'cv317_25111.txt',
#  'cv318_11146.txt',
#  'cv319_16459.txt',
#  'cv320_9693.txt',
#  'cv321_14191.txt',
#  'cv322_21820.txt',
#  'cv323_29633.txt',
#  'cv324_7502.txt',
#  'cv325_18330.txt',
#  'cv326_14777.txt',
#  'cv327_21743.txt',
#  'cv328_10908.txt',
#  'cv329_29293.txt',
#  'cv330_29675.txt',
#  'cv331_8656.txt',
#  'cv332_17997.txt',
#  'cv333_9443.txt',
#  'cv334_0074.txt',
#  'cv335_16299.txt',
#  'cv336_10363.txt',
#  'cv337_29061.txt',
#  'cv338_9183.txt',
#  'cv339_22452.txt',
#  'cv340_14776.txt',
#  'cv341_25667.txt',
#  'cv342_20917.txt',
#  'cv343_10906.txt',
#  'cv344_5376.txt',
#  'cv345_9966.txt',
#  'cv346_19198.txt',
#  'cv347_14722.txt',
#  'cv348_19207.txt',
#  'cv349_15032.txt',
#  'cv350_22139.txt',
#  'cv351_17029.txt',
#  'cv352_5414.txt',
#  'cv353_19197.txt',
#  'cv354_8573.txt',
#  'cv355_18174.txt',
#  'cv356_26170.txt',
#  'cv357_14710.txt',
#  'cv358_11557.txt',
#  'cv359_6751.txt',
#  'cv360_8927.txt',
#  'cv361_28738.txt',
#  'cv362_16985.txt',
#  'cv363_29273.txt',
#  'cv364_14254.txt',
#  'cv365_12442.txt',
#  'cv366_10709.txt',
#  'cv367_24065.txt',
#  'cv368_11090.txt',
#  'cv369_14245.txt',
#  'cv370_5338.txt',
#  'cv371_8197.txt',
#  'cv372_6654.txt',
#  'cv373_21872.txt',
#  'cv374_26455.txt',
#  'cv375_9932.txt',
#  'cv376_20883.txt',
#  'cv377_8440.txt',
#  'cv378_21982.txt',
#  'cv379_23167.txt',
#  'cv380_8164.txt',
#  'cv381_21673.txt',
#  'cv382_8393.txt',
#  'cv383_14662.txt',
#  'cv384_18536.txt',
#  'cv385_29621.txt',
#  'cv386_10229.txt',
#  'cv387_12391.txt',
#  'cv388_12810.txt',
#  'cv389_9611.txt',
#  'cv390_12187.txt',
#  'cv391_11615.txt',
#  'cv392_12238.txt',
#  'cv393_29234.txt',
#  'cv394_5311.txt',
#  'cv395_11761.txt',
#  'cv396_19127.txt',
#  'cv397_28890.txt',
#  'cv398_17047.txt',
#  'cv399_28593.txt',
#  'cv400_20631.txt',
#  'cv401_13758.txt',
#  'cv402_16097.txt',
#  'cv403_6721.txt',
#  'cv404_21805.txt',
#  'cv405_21868.txt',
#  'cv406_22199.txt',
#  'cv407_23928.txt',
#  'cv408_5367.txt',
#  'cv409_29625.txt',
#  'cv410_25624.txt',
#  'cv411_16799.txt',
#  'cv412_25254.txt',
#  'cv413_7893.txt',
#  'cv414_11161.txt',
#  'cv415_23674.txt',
#  'cv416_12048.txt',
#  'cv417_14653.txt',
#  'cv418_16562.txt',
#  'cv419_14799.txt',
#  'cv420_28631.txt',
#  'cv421_9752.txt',
#  'cv422_9632.txt',
#  'cv423_12089.txt',
#  'cv424_9268.txt',
#  'cv425_8603.txt',
#  'cv426_10976.txt',
#  'cv427_11693.txt',
#  'cv428_12202.txt',
#  'cv429_7937.txt',
#  'cv430_18662.txt',
#  'cv431_7538.txt',
#  'cv432_15873.txt',
#  'cv433_10443.txt',
#  'cv434_5641.txt',
#  'cv435_24355.txt',
#  'cv436_20564.txt',
#  'cv437_24070.txt',
#  'cv438_8500.txt',
#  'cv439_17633.txt',
#  'cv440_16891.txt',
#  'cv441_15276.txt',
#  'cv442_15499.txt',
#  'cv443_22367.txt',
#  'cv444_9975.txt',
#  'cv445_26683.txt',
#  'cv446_12209.txt',
#  'cv447_27334.txt',
#  'cv448_16409.txt',
#  'cv449_9126.txt',
#  'cv450_8319.txt',
#  'cv451_11502.txt',
#  'cv452_5179.txt',
#  'cv453_10911.txt',
#  'cv454_21961.txt',
#  'cv455_28866.txt',
#  'cv456_20370.txt',
#  'cv457_19546.txt',
#  'cv458_9000.txt',
#  'cv459_21834.txt',
#  'cv460_11723.txt',
#  'cv461_21124.txt',
#  'cv462_20788.txt',
#  'cv463_10846.txt',
#  'cv464_17076.txt',
#  'cv465_23401.txt',
#  'cv466_20092.txt',
#  'cv467_26610.txt',
#  'cv468_16844.txt',
#  'cv469_21998.txt',
#  'cv470_17444.txt',
#  'cv471_18405.txt',
#  'cv472_29140.txt',
#  'cv473_7869.txt',
#  'cv474_10682.txt',
#  'cv475_22978.txt',
#  'cv476_18402.txt',
#  'cv477_23530.txt',
#  'cv478_15921.txt',
#  'cv479_5450.txt',
#  'cv480_21195.txt',
#  'cv481_7930.txt',
#  'cv482_11233.txt',
#  'cv483_18103.txt',
#  'cv484_26169.txt',
#  'cv485_26879.txt',
#  'cv486_9788.txt',
#  'cv487_11058.txt',
#  'cv488_21453.txt',
#  'cv489_19046.txt',
#  'cv490_18986.txt',
#  'cv491_12992.txt',
#  'cv492_19370.txt',
#  'cv493_14135.txt',
#  'cv494_18689.txt',
#  'cv495_16121.txt',
#  'cv496_11185.txt',
#  'cv497_27086.txt',
#  'cv498_9288.txt',
#  'cv499_11407.txt',
#  'cv500_10722.txt',
#  'cv501_12675.txt',
#  'cv502_10970.txt',
#  'cv503_11196.txt',
#  'cv504_29120.txt',
#  'cv505_12926.txt',
#  'cv506_17521.txt',
#  'cv507_9509.txt',
#  'cv508_17742.txt',
#  'cv509_17354.txt',
#  'cv510_24758.txt',
#  'cv511_10360.txt',
#  'cv512_17618.txt',
#  'cv513_7236.txt',
#  'cv514_12173.txt',
#  'cv515_18484.txt',
#  'cv516_12117.txt',
#  'cv517_20616.txt',
#  'cv518_14798.txt',
#  'cv519_16239.txt',
#  'cv520_13297.txt',
#  'cv521_1730.txt',
#  'cv522_5418.txt',
#  'cv523_18285.txt',
#  'cv524_24885.txt',
#  'cv525_17930.txt',
#  'cv526_12868.txt',
#  'cv527_10338.txt',
#  'cv528_11669.txt',
#  'cv529_10972.txt',
#  'cv530_17949.txt',
#  'cv531_26838.txt',
#  'cv532_6495.txt',
#  'cv533_9843.txt',
#  'cv534_15683.txt',
#  'cv535_21183.txt',
#  'cv536_27221.txt',
#  'cv537_13516.txt',
#  'cv538_28485.txt',
#  'cv539_21865.txt',
#  'cv540_3092.txt',
#  'cv541_28683.txt',
#  'cv542_20359.txt',
#  'cv543_5107.txt',
#  'cv544_5301.txt',
#  'cv545_12848.txt',
#  'cv546_12723.txt',
#  'cv547_18043.txt',
#  'cv548_18944.txt',
#  'cv549_22771.txt',
#  'cv550_23226.txt',
#  'cv551_11214.txt',
#  'cv552_0150.txt',
#  'cv553_26965.txt',
#  'cv554_14678.txt',
#  'cv555_25047.txt',
#  'cv556_16563.txt',
#  'cv557_12237.txt',
#  'cv558_29376.txt',
#  'cv559_0057.txt',
#  'cv560_18608.txt',
#  'cv561_9484.txt',
#  'cv562_10847.txt',
#  'cv563_18610.txt',
#  'cv564_12011.txt',
#  'cv565_29403.txt',
#  'cv566_8967.txt',
#  'cv567_29420.txt',
#  'cv568_17065.txt',
#  'cv569_26750.txt',
#  'cv570_28960.txt',
#  'cv571_29292.txt',
#  'cv572_20053.txt',
#  'cv573_29384.txt',
#  'cv574_23191.txt',
#  'cv575_22598.txt',
#  'cv576_15688.txt',
#  'cv577_28220.txt',
#  'cv578_16825.txt',
#  'cv579_12542.txt',
#  'cv580_15681.txt',
#  'cv581_20790.txt',
#  'cv582_6678.txt',
#  'cv583_29465.txt',
#  'cv584_29549.txt',
#  'cv585_23576.txt',
#  'cv586_8048.txt',
#  'cv587_20532.txt',
#  'cv588_14467.txt',
#  'cv589_12853.txt',
#  'cv590_20712.txt',
#  'cv591_24887.txt',
#  'cv592_23391.txt',
#  'cv593_11931.txt',
#  'cv594_11945.txt',
#  'cv595_26420.txt',
#  'cv596_4367.txt',
#  'cv597_26744.txt',
#  'cv598_18184.txt',
#  'cv599_22197.txt',
#  'cv600_25043.txt',
#  'cv601_24759.txt',
#  'cv602_8830.txt',
#  'cv603_18885.txt',
#  'cv604_23339.txt',
#  'cv605_12730.txt',
#  'cv606_17672.txt',
#  'cv607_8235.txt',
#  'cv608_24647.txt',
#  'cv609_25038.txt',
#  'cv610_24153.txt',
#  'cv611_2253.txt',
#  'cv612_5396.txt',
#  'cv613_23104.txt',
#  'cv614_11320.txt',
#  'cv615_15734.txt',
#  'cv616_29187.txt',
#  'cv617_9561.txt',
#  'cv618_9469.txt',
#  'cv619_13677.txt',
#  'cv620_2556.txt',
#  'cv621_15984.txt',
#  'cv622_8583.txt',
#  'cv623_16988.txt',
#  'cv624_11601.txt',
#  'cv625_13518.txt',
#  'cv626_7907.txt',
#  'cv627_12603.txt',
#  'cv628_20758.txt',
#  'cv629_16604.txt',
#  'cv630_10152.txt',
#  'cv631_4782.txt',
#  'cv632_9704.txt',
#  'cv633_29730.txt',
#  'cv634_11989.txt',
#  'cv635_0984.txt',
#  'cv636_16954.txt',
#  'cv637_13682.txt',
#  'cv638_29394.txt',
#  'cv639_10797.txt',
#  'cv640_5380.txt',
#  'cv641_13412.txt',
#  'cv642_29788.txt',
#  'cv643_29282.txt',
#  'cv644_18551.txt',
#  'cv645_17078.txt',
#  'cv646_16817.txt',
#  'cv647_15275.txt',
#  'cv648_17277.txt',
#  'cv649_13947.txt',
#  'cv650_15974.txt',
#  'cv651_11120.txt',
#  'cv652_15653.txt',
#  'cv653_2107.txt',
#  'cv654_19345.txt',
#  'cv655_12055.txt',
#  'cv656_25395.txt',
#  'cv657_25835.txt',
#  'cv658_11186.txt',
#  'cv659_21483.txt',
#  'cv660_23140.txt',
#  'cv661_25780.txt',
#  'cv662_14791.txt',
#  'cv663_14484.txt',
#  'cv664_4264.txt',
#  'cv665_29386.txt',
#  'cv666_20301.txt',
#  'cv667_19672.txt',
#  'cv668_18848.txt',
#  'cv669_24318.txt',
#  'cv670_2666.txt',
#  'cv671_5164.txt',
#  'cv672_27988.txt',
#  'cv673_25874.txt',
#  'cv674_11593.txt',
#  'cv675_22871.txt',
#  'cv676_22202.txt',
#  'cv677_18938.txt',
#  'cv678_14887.txt',
#  'cv679_28221.txt',
#  'cv680_10533.txt',
#  'cv681_9744.txt',
#  'cv682_17947.txt',
#  'cv683_13047.txt',
#  'cv684_12727.txt',
#  'cv685_5710.txt',
#  'cv686_15553.txt',
#  'cv687_22207.txt',
#  'cv688_7884.txt',
#  'cv689_13701.txt',
#  'cv690_5425.txt',
#  'cv691_5090.txt',
#  'cv692_17026.txt',
#  'cv693_19147.txt',
#  'cv694_4526.txt',
#  'cv695_22268.txt',
#  'cv696_29619.txt',
#  'cv697_12106.txt',
#  'cv698_16930.txt',
#  'cv699_7773.txt',
#  'cv700_23163.txt',
#  'cv701_15880.txt',
#  'cv702_12371.txt',
#  'cv703_17948.txt',
#  'cv704_17622.txt',
#  'cv705_11973.txt',
#  'cv706_25883.txt',
#  'cv707_11421.txt',
#  'cv708_28539.txt',
#  'cv709_11173.txt',
#  'cv710_23745.txt',
#  'cv711_12687.txt',
#  'cv712_24217.txt',
#  'cv713_29002.txt',
#  'cv714_19704.txt',
#  'cv715_19246.txt',
#  'cv716_11153.txt',
#  'cv717_17472.txt',
#  'cv718_12227.txt',
#  'cv719_5581.txt',
#  'cv720_5383.txt',
#  'cv721_28993.txt',
#  'cv722_7571.txt',
#  'cv723_9002.txt',
#  'cv724_15265.txt',
#  'cv725_10266.txt',
#  'cv726_4365.txt',
#  'cv727_5006.txt',
#  'cv728_17931.txt',
#  'cv729_10475.txt',
#  'cv730_10729.txt',
#  'cv731_3968.txt',
#  'cv732_13092.txt',
#  'cv733_9891.txt',
#  'cv734_22821.txt',
#  'cv735_20218.txt',
#  'cv736_24947.txt',
#  'cv737_28733.txt',
#  'cv738_10287.txt',
#  'cv739_12179.txt',
#  'cv740_13643.txt',
#  'cv741_12765.txt',
#  'cv742_8279.txt',
#  'cv743_17023.txt',
#  'cv744_10091.txt',
#  'cv745_14009.txt',
#  'cv746_10471.txt',
#  'cv747_18189.txt',
#  'cv748_14044.txt',
#  'cv749_18960.txt',
#  'cv750_10606.txt',
#  'cv751_17208.txt',
#  'cv752_25330.txt',
#  'cv753_11812.txt',
#  'cv754_7709.txt',
#  'cv755_24881.txt',
#  'cv756_23676.txt',
#  'cv757_10668.txt',
#  'cv758_9740.txt',
#  'cv759_15091.txt',
#  'cv760_8977.txt',
#  'cv761_13769.txt',
#  'cv762_15604.txt',
#  'cv763_16486.txt',
#  'cv764_12701.txt',
#  'cv765_20429.txt',
#  'cv766_7983.txt',
#  'cv767_15673.txt',
#  'cv768_12709.txt',
#  'cv769_8565.txt',
#  'cv770_11061.txt',
#  'cv771_28466.txt',
#  'cv772_12971.txt',
#  'cv773_20264.txt',
#  'cv774_15488.txt',
#  'cv775_17966.txt',
#  'cv776_21934.txt',
#  'cv777_10247.txt',
#  'cv778_18629.txt',
#  'cv779_18989.txt',
#  'cv780_8467.txt',
#  'cv781_5358.txt',
#  'cv782_21078.txt',
#  'cv783_14724.txt',
#  'cv784_16077.txt',
#  'cv785_23748.txt',
#  'cv786_23608.txt',
#  'cv787_15277.txt',
#  'cv788_26409.txt',
#  'cv789_12991.txt',
#  'cv790_16202.txt',
#  'cv791_17995.txt',
#  'cv792_3257.txt',
#  'cv793_15235.txt',
#  'cv794_17353.txt',
#  'cv795_10291.txt',
#  'cv796_17243.txt',
#  'cv797_7245.txt',
#  'cv798_24779.txt',
#  'cv799_19812.txt',
#  'cv800_13494.txt',
#  'cv801_26335.txt',
#  'cv802_28381.txt',
#  'cv803_8584.txt',
#  'cv804_11763.txt',
#  'cv805_21128.txt',
#  'cv806_9405.txt',
#  'cv807_23024.txt',
#  'cv808_13773.txt',
#  'cv809_5012.txt',
#  'cv810_13660.txt',
#  'cv811_22646.txt',
#  'cv812_19051.txt',
#  'cv813_6649.txt',
#  'cv814_20316.txt',
#  'cv815_23466.txt',
#  'cv816_15257.txt',
#  'cv817_3675.txt',
#  'cv818_10698.txt',
#  'cv819_9567.txt',
#  'cv820_24157.txt',
#  'cv821_29283.txt',
#  'cv822_21545.txt',
#  'cv823_17055.txt',
#  'cv824_9335.txt',
#  'cv825_5168.txt',
#  'cv826_12761.txt',
#  'cv827_19479.txt',
#  'cv828_21392.txt',
#  'cv829_21725.txt',
#  'cv830_5778.txt',
#  'cv831_16325.txt',
#  'cv832_24713.txt',
#  'cv833_11961.txt',
#  'cv834_23192.txt',
#  'cv835_20531.txt',
#  'cv836_14311.txt',
#  'cv837_27232.txt',
#  'cv838_25886.txt',
#  'cv839_22807.txt',
#  'cv840_18033.txt',
#  'cv841_3367.txt',
#  'cv842_5702.txt',
#  'cv843_17054.txt',
#  'cv844_13890.txt',
#  'cv845_15886.txt',
#  'cv846_29359.txt',
#  'cv847_20855.txt',
#  'cv848_10061.txt',
#  'cv849_17215.txt',
#  'cv850_18185.txt',
#  'cv851_21895.txt',
#  'cv852_27512.txt',
#  'cv853_29119.txt',
#  'cv854_18955.txt',
#  'cv855_22134.txt',
#  'cv856_28882.txt',
#  'cv857_17527.txt',
#  'cv858_20266.txt',
#  'cv859_15689.txt',
#  'cv860_15520.txt',
#  'cv861_12809.txt',
#  'cv862_15924.txt',
#  'cv863_7912.txt',
#  'cv864_3087.txt',
#  'cv865_28796.txt',
#  'cv866_29447.txt',
#  'cv867_18362.txt',
#  'cv868_12799.txt',
#  'cv869_24782.txt',
#  'cv870_18090.txt',
#  'cv871_25971.txt',
#  'cv872_13710.txt',
#  'cv873_19937.txt',
#  'cv874_12182.txt',
#  'cv875_5622.txt',
#  'cv876_9633.txt',
#  'cv877_29132.txt',
#  'cv878_17204.txt',
#  'cv879_16585.txt',
#  'cv880_29629.txt',
#  'cv881_14767.txt',
#  'cv882_10042.txt',
#  'cv883_27621.txt',
#  'cv884_15230.txt',
#  'cv885_13390.txt',
#  'cv886_19210.txt',
#  'cv887_5306.txt',
#  'cv888_25678.txt',
#  'cv889_22670.txt',
#  'cv890_3515.txt',
#  'cv891_6035.txt',
#  'cv892_18788.txt',
#  'cv893_26731.txt',
#  'cv894_22140.txt',
#  'cv895_22200.txt',
#  'cv896_17819.txt',
#  'cv897_11703.txt',
#  'cv898_1576.txt',
#  'cv899_17812.txt',
#  'cv900_10800.txt',
#  'cv901_11934.txt',
#  'cv902_13217.txt',
#  'cv903_18981.txt',
#  'cv904_25663.txt',
#  'cv905_28965.txt',
#  'cv906_12332.txt',
#  'cv907_3193.txt',
#  'cv908_17779.txt',
#  'cv909_9973.txt',
#  'cv910_21930.txt',
#  'cv911_21695.txt',
#  'cv912_5562.txt',
#  'cv913_29127.txt',
#  'cv914_2856.txt',
#  'cv915_9342.txt',
#  'cv916_17034.txt',
#  'cv917_29484.txt',
#  'cv918_27080.txt',
#  'cv919_18155.txt',
#  'cv920_29423.txt',
#  'cv921_13988.txt',
#  'cv922_10185.txt',
#  'cv923_11951.txt',
#  'cv924_29397.txt',
#  'cv925_9459.txt',
#  'cv926_18471.txt',
#  'cv927_11471.txt',
#  'cv928_9478.txt',
#  'cv929_1841.txt',
#  'cv930_14949.txt',
#  'cv931_18783.txt',
#  'cv932_14854.txt',
#  'cv933_24953.txt',
#  'cv934_20426.txt',
#  'cv935_24977.txt',
#  'cv936_17473.txt',
#  'cv937_9816.txt',
#  'cv938_10706.txt',
#  'cv939_11247.txt',
#  'cv940_18935.txt',
#  'cv941_10718.txt',
#  'cv942_18509.txt',
#  'cv943_23547.txt',
#  'cv944_15042.txt',
#  'cv945_13012.txt',
#  'cv946_20084.txt',
#  'cv947_11316.txt',
#  'cv948_25870.txt',
#  'cv949_21565.txt',
#  'cv950_13478.txt',
#  'cv951_11816.txt',
#  'cv952_26375.txt',
#  'cv953_7078.txt',
#  'cv954_19932.txt',
#  'cv955_26154.txt',
#  'cv956_12547.txt',
#  'cv957_9059.txt',
#  'cv958_13020.txt',
#  'cv959_16218.txt',
#  'cv960_28877.txt',
#  'cv961_5578.txt',
#  'cv962_9813.txt',
#  'cv963_7208.txt',
#  'cv964_5794.txt',
#  'cv965_26688.txt',
#  'cv966_28671.txt',
#  'cv967_5626.txt',
#  'cv968_25413.txt',
#  'cv969_14760.txt',
#  'cv970_19532.txt',
#  'cv971_11790.txt',
#  'cv972_26837.txt',
#  'cv973_10171.txt',
#  'cv974_24303.txt',
#  'cv975_11920.txt',
#  'cv976_10724.txt',
#  'cv977_4776.txt',
#  'cv978_22192.txt',
#  'cv979_2029.txt',
#  'cv980_11851.txt',
#  'cv981_16679.txt',
#  'cv982_22209.txt',
#  'cv983_24219.txt',
#  'cv984_14006.txt',
#  'cv985_5964.txt',
#  'cv986_15092.txt',
#  'cv987_7394.txt',
#  'cv988_20168.txt',
#  'cv989_17297.txt',
#  'cv990_12443.txt',
#  'cv991_19973.txt',
#  'cv992_12806.txt',
#  'cv993_29565.txt',
#  'cv994_13229.txt',
#  'cv995_23113.txt',
#  'cv996_12447.txt',
#  'cv997_5152.txt',
#  'cv998_15691.txt',
#  'cv999_14636.txt']

# %%
# Assign that list to a variable
negative_files = os.listdir('data/movie_reviews/negative')

# %%
# Inspect first element in the list
negative_files[0]
# Out:
# 'cv000_29416.txt'

# %%
## EXERCISE. How many reviews are there in the 'positive' folder?
##           How many in the 'negative' one?

negative_path = "data/movie_reviews/negative/"
positive_path = "data/movie_reviews/positive/"

## CHALLENGE: Find a list of files and folders on your desktop.

# %% [markdown]
# ## Corpus
#
# Unfortunately, freely available text collections in the archaeology domain are rare. Instead, we will apply text mining methods to a toy corpus distributed with NLTK: movie reviews. These have been divided into positive and negative categories, with one thousand of each.
#
# In essence, our task will be to learn the vocabulary of positive and negative reviews.

# %%
# Open the first file from 'negative_files'
open('data/movie_reviews/negative/cv000_29416.txt').read()
# Out:
# 'plot : two teen couples go to a church party , drink and then drive . \nthey get into an accident . \none of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . \nwhat\'s the deal ? \nwatch the movie and " sorta " find out . . . \ncritique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package . \nwhich is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn\'t snag this one correctly . \nthey seem to have taken this pretty neat concept , but executed it terribly . \nso what are the problems with the movie ? \nwell , its main problem is that it\'s simply too jumbled . \nit starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what\'s going on . \nthere are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained . \nnow i personally don\'t mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film\'s biggest problem . \nit\'s obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes . \nand do they make things entertaining , thrilling or even engaging , in the meantime ? \nnot really . \nthe sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn\'t the make the film all that more entertaining . \ni guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding . \ni mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! ! \nokay , we get it . . . there \nare people chasing her and we don\'t know who they are . \ndo we really need to see it over and over again ? \nhow about giving us different scenes offering further insight into all of the strangeness going down in the movie ? \napparently , the studio took this film away from its director and chopped it up themselves , and it shows . \nthere might\'ve been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense . \nthe actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood . \nbut my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character\'s unraveling . \noverall , the film doesn\'t stick because it doesn\'t entertain , it\'s confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it . \noh , and by the way , this is not a horror or teen slasher flick . . . it\'s \njust packaged to look that way because someone is apparently assuming that the genre is still hot with the kids . \nit also wrapped production two years ago and has been sitting on the shelves ever since . \nwhatever . . . skip \nit ! \nwhere\'s joblo coming from ? \na nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 )  ...

# %%
# When opening others, filenames change but the path doesn't!
negative_path = "data/movie_reviews/negative/"
open(negative_path+'cv000_29416.txt').read()
# Out:
# 'plot : two teen couples go to a church party , drink and then drive . \nthey get into an accident . \none of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . \nwhat\'s the deal ? \nwatch the movie and " sorta " find out . . . \ncritique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package . \nwhich is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn\'t snag this one correctly . \nthey seem to have taken this pretty neat concept , but executed it terribly . \nso what are the problems with the movie ? \nwell , its main problem is that it\'s simply too jumbled . \nit starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what\'s going on . \nthere are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained . \nnow i personally don\'t mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film\'s biggest problem . \nit\'s obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes . \nand do they make things entertaining , thrilling or even engaging , in the meantime ? \nnot really . \nthe sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn\'t the make the film all that more entertaining . \ni guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding . \ni mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! ! \nokay , we get it . . . there \nare people chasing her and we don\'t know who they are . \ndo we really need to see it over and over again ? \nhow about giving us different scenes offering further insight into all of the strangeness going down in the movie ? \napparently , the studio took this film away from its director and chopped it up themselves , and it shows . \nthere might\'ve been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense . \nthe actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood . \nbut my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character\'s unraveling . \noverall , the film doesn\'t stick because it doesn\'t entertain , it\'s confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it . \noh , and by the way , this is not a horror or teen slasher flick . . . it\'s \njust packaged to look that way because someone is apparently assuming that the genre is still hot with the kids . \nit also wrapped production two years ago and has been sitting on the shelves ever since . \nwhatever . . . skip \nit ! \nwhere\'s joblo coming from ? \na nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 )  ...

# %%
# Read all files and assign to a variable
negative_reviews = [open(negative_path+name,'r').read() for name in negative_files]

# %%
# NOTE: If you are using OSX, your operating system may sometimes
# include hidden files in your folders that confuse Python.

# If you get an error while running the above line, try including an 'if' condition
# in your list comprehension to prevent Python from tripping over these.

# For example:
negative_reviews = [open(negative_path+name,'r').read() for name in negative_files if name[-4:]=='.txt']

# %%
# Inspect

negative_reviews[0]
# Out:
# 'plot : two teen couples go to a church party , drink and then drive . \nthey get into an accident . \none of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . \nwhat\'s the deal ? \nwatch the movie and " sorta " find out . . . \ncritique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package . \nwhich is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn\'t snag this one correctly . \nthey seem to have taken this pretty neat concept , but executed it terribly . \nso what are the problems with the movie ? \nwell , its main problem is that it\'s simply too jumbled . \nit starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what\'s going on . \nthere are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained . \nnow i personally don\'t mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film\'s biggest problem . \nit\'s obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes . \nand do they make things entertaining , thrilling or even engaging , in the meantime ? \nnot really . \nthe sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn\'t the make the film all that more entertaining . \ni guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding . \ni mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! ! \nokay , we get it . . . there \nare people chasing her and we don\'t know who they are . \ndo we really need to see it over and over again ? \nhow about giving us different scenes offering further insight into all of the strangeness going down in the movie ? \napparently , the studio took this film away from its director and chopped it up themselves , and it shows . \nthere might\'ve been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense . \nthe actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood . \nbut my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character\'s unraveling . \noverall , the film doesn\'t stick because it doesn\'t entertain , it\'s confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it . \noh , and by the way , this is not a horror or teen slasher flick . . . it\'s \njust packaged to look that way because someone is apparently assuming that the genre is still hot with the kids . \nit also wrapped production two years ago and has been sitting on the shelves ever since . \nwhatever . . . skip \nit ! \nwhere\'s joblo coming from ? \na nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 )  ...

# %%
# Repeat process for positive reviews

positive_path = 'data/movie_reviews/positive/'
positive_files = os.listdir(positive_path)
positive_reviews = [open(positive_path+name,'r').read() for name in positive_files]

# %%
# Inspect first element in list
positive_reviews[0]
# Out:
# 'films adapted from comic books have had plenty of success , whether they\'re about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there\'s never really been a comic book like from hell before . \nfor starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid \'80s with a 12-part series called the watchmen . \nto say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd . \nthe book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes . \nin other words , don\'t dismiss this film because of its source . \nif you can get past the whole comic book thing , you might find another stumbling block in from hell\'s directors , albert and allen hughes . \ngetting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that\'s set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ? \nthe ghetto in question is , of course , whitechapel in 1888 london\'s east end . \nit\'s a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious psychopath who has been carving through their profession with surgical precision . \nwhen the first stiff turns up , copper peter godley ( robbie coltrane , the world is not enough ) calls in inspector frederick abberline ( johnny depp , blow ) to crack the case . \nabberline , a widower , has prophetic dreams he unsuccessfully tries to quell with copious amounts of absinthe and opium . \nupon arriving in whitechapel , he befriends an unfortunate named mary kelly ( heather graham , say it isn\'t so ) and proceeds to investigate the horribly gruesome crimes that even the police surgeon can\'t stomach . \ni don\'t think anyone needs to be briefed on jack the ripper , so i won\'t go into the particulars here , other than to say moore and campbell have a unique and interesting theory about both the identity of the killer and the reasons he chooses to slay . \nin the comic , they don\'t bother cloaking the identity of the ripper , but screenwriters terry hayes ( vertical limit ) and rafael yglesias ( les mis ? rables ) do a good job of keeping him hidden from viewers until the very end . \nit\'s funny to watch the locals blindly point the finger of blame at jews and indians because , after all , an englishman could never be capable of committing such ghastly acts . \nand from hell\'s ending had me whistling the stonecutters song from the simpsons for days ( " who holds back the electric car/who made steve guttenberg a star ? " ) . \ndon\'t worry - it\'ll all make sense when you see it . \nnow onto from hell\'s appearance : it\'s certainly dark and bleak enough , and it\'s surprising to see how much more it looks like a tim burton film than planet of the apes did ( at times , it seems like sleepy hollow 2 ) . \nthe print i saw wasn\'t completely finished ( both color and music had not been finalized , so no comments about marilyn manson ) , but cinematographer peter deming ( don\'t say a word ) ably captures the dreariness of victorian-era london and helped make the flashy killing scenes remind me of the crazy flashbacks in twin peaks , even though the violence in the film pales in comparison to that in the black-and-white comic . \noscar winner martin childs\' ( shakespeare in love ) production design turns the original prague surroundings into one creepy place . \neven the acting in from hell is solid , with the dreamy depp turning in a typically strong performance and deftly handling a british accent . \nians holm ( joe gould\'s secret ) and richardson ( 102 dalmatians ) log in great supporting roles , but t ...

# %%
## EXERCISE. How long is the list of positive movie reviews? Negative reviews?
##           Do these match the number of files you had observed in the folders earlier?

# %% [markdown]
# # 3. Pre-Processing
#
# The pre-processing phase of our workflow transforms the strings that Python has read from the plaintext files into useful sets of features. Not only will we tokenise the texts, as we have previously, but we will perform three further steps described in the lectures: <i>stop word</i> removal, <i>lemmatisation</i> of nouns, and low-frequency word removal.
#
# Although pre-processing feels like a nitty-gritty task, it is important to recognize that how we pre-process our texts depends on the questions we are trying to answer. Not every project lemmatises or stems its vocabulary. Perhaps we can imagine research questions in which the grammmatical functions indicated by word endings might be useful.

# %% [markdown]
# ## Tokenise

# %%
from nltk import word_tokenize

# %%
# Tokenise first negative review

word_tokenize(negative_reviews[0])
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'to',
#  'a',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'and',
#  'then',
#  'drive',
#  '.',
#  'they',
#  'get',
#  'into',
#  'an',
#  'accident',
#  '.',
#  'one',
#  'of',
#  'the',
#  'guys',
#  'dies',
#  ',',
#  'but',
#  'his',
#  'girlfriend',
#  'continues',
#  'to',
#  'see',
#  'him',
#  'in',
#  'her',
#  'life',
#  ',',
#  'and',
#  'has',
#  'nightmares',
#  '.',
#  'what',
#  "'s",
#  'the',
#  'deal',
#  '?',
#  'watch',
#  'the',
#  'movie',
#  'and',
#  '``',
#  'sorta',
#  '``',
#  'find',
#  'out',
#  '.',
#  '.',
#  '.',
#  'critique',
#  ':',
#  'a',
#  'mind-fuck',
#  'movie',
#  'for',
#  'the',
#  'teen',
#  'generation',
#  'that',
#  'touches',
#  'on',
#  'a',
#  'very',
#  'cool',
#  'idea',
#  ',',
#  'but',
#  'presents',
#  'it',
#  'in',
#  'a',
#  'very',
#  'bad',
#  'package',
#  '.',
#  'which',
#  'is',
#  'what',
#  'makes',
#  'this',
#  'review',
#  'an',
#  'even',
#  'harder',
#  'one',
#  'to',
#  'write',
#  ',',
#  'since',
#  'i',
#  'generally',
#  'applaud',
#  'films',
#  'which',
#  'attempt',
#  'to',
#  'break',
#  'the',
#  'mold',
#  ',',
#  'mess',
#  'with',
#  'your',
#  'head',
#  'and',
#  'such',
#  '(',
#  'lost',
#  'highway',
#  '&',
#  'memento',
#  ')',
#  ',',
#  'but',
#  'there',
#  'are',
#  'good',
#  'and',
#  'bad',
#  'ways',
#  'of',
#  'making',
#  'all',
#  'types',
#  'of',
#  'films',
#  ',',
#  'and',
#  'these',
#  'folks',
#  'just',
#  'did',
#  "n't",
#  'snag',
#  'this',
#  'one',
#  'correctly',
#  '.',
#  'they',
#  'seem',
#  'to',
#  'have',
#  'taken',
#  'this',
#  'pretty',
#  'neat',
#  'concept',
#  ',',
#  'but',
#  'executed',
#  'it',
#  'terribly',
#  '.',
#  'so',
#  'what',
#  'are',
#  'the',
#  'problems',
#  'with',
#  'the',
#  'movie',
#  '?',
#  'well',
#  ',',
#  'its',
#  'main',
#  'problem',
#  'is',
#  'that',
#  'it',
#  "'s",
#  'simply',
#  'too',
#  'jumbled',
#  '.',
#  'it',
#  'starts',
#  'off',
#  '``',
#  'normal',
#  '``',
#  'but',
#  'then',
#  'downshifts',
#  'into',
#  'this',
#  '``',
#  'fantasy',
#  '``',
#  'world',
#  'in',
#  'which',
#  'you',
#  ',',
#  'as',
#  'an',
#  'audience',
#  'member',
#  ',',
#  'have',
#  'no',
#  'idea',
#  'what',
#  "'s",
#  'going',
#  'on',
#  '.',
#  'there',
#  'are',
#  'dreams',
#  ',',
#  'there',
#  'are',
#  'characters',
#  'coming',
#  'back',
#  'from',
#  'the',
#  'dead',
#  ',',
#  'there',
#  'are',
#  'others',
#  'who',
#  'look',
#  'like',
#  'the',
#  'dead',
#  ',',
#  'there',
#  'are',
#  'strange',
#  'apparitions',
#  ',',
#  'there',
#  'are',
#  'disappearances',
#  ',',
#  'there',
#  'are',
#  'a',
#  'looooot',
#  'of',
#  'chase',
#  'scenes',
#  ',',
#  'there',
#  'are',
#  'tons',
#  'of',
#  'weird',
#  'things',
#  'that',
#  'happen',
#  ',',
#  'and',
#  'most',
#  'of',
#  'it',
#  'is',
#  'simply',
#  'not',
#  'explained',
#  '.',
#  'now',
#  'i',
#  'personally',
#  'do',
#  "n't",
#  'mind',
#  'trying',
#  'to',
#  'unravel',
#  'a',
#  'film',
#  'every',
#  'now',
#  'and',
#  'then',
#  ',',
#  'but',
#  'when',
#  'all',
#  'it',
#  'does',
#  'is',
#  'give',
#  'me',
#  'the',
#  'same',
#  'clue',
#  'over',
#  'and',
#  'over',
#  'again',
#  ',',
#  'i',
#  'get',
#  'kind',
#  'of',
#  'fed',
#  'up',
#  'after',
#  'a',
#  'while',
#  ',',
#  'which',
#  'is',
#  'this',
#  'film',
#  "'s",
#  'biggest',
#  'problem',
#  '.',
#  'it',
#  "'s",
#  'obviously',
#  'got',
#  'this',
#  'big',
#  'secret',
#  'to',
#  'hide',
#  ',',
#  'but',
#  'it',
#  'seems',
#  'to',
#  'want',
#  'to',
#  'hide',
#  'it',
#  'completely',
#  'until',
#  'its',
#  'final',
#  'five',
#  'minutes',
#  '.',
#  'and',
#  'do',
#  'they',
#  'make',
#  'things',
#  'entertaining',
#  ',',
#  'thrilling',
#  'or',
#  'even',
#  'engaging',
#  ',',
#  'in',
#  'the',
#  'meantime',
#  '?',
#  'not',
#  'really',
#  '.',
#  'the',
#  'sad',
#  'part',
#  'is',
#  'that',
#  'the',
#  'arrow',
#  'and',
#  'i',
#  'both',
#  'dig',
#  'on',
#  'flicks',
#  'like',
#  'this',
#  ',',
#  'so',
#  'we',
#  'actually',
#  'figured',
#  'most',
#  'of',
#  'it',
#  'out',
#  'by',
#  'the',
#  'half-way',
#  'point',
#  ',',
#  'so',
#  'all',
#  'of',
#  'the',
#  'strangeness',
#  'after',
#  'that',
#  'did',
#  'start',
#  'to',
#  'make',
#  'a',
#  'little',
#  'bit',
#  'of',
#  'sense',
#  ',',
#  'but',
#  'it',
#  'still',
#  'did',
#  "n't",
#  'the',
#  'make',
#  'the',
#  'film',
#  'all',
#  'that',
#  'more',
#  'entertaining',
#  '.',
#  'i',
#  'guess',
#  'the',
#  'bottom',
#  'line',
#  'with',
#  'movies',
#  'like',
#  'this',
#  'is',
#  'that',
#  'you',
#  'should',
#  'always',
#  'make',
#  'sure',
#  'that',
#  'the',
#  'audience',
#  'is',
#  '``',
#  'into',
#  'it',
#  '``',
#  'even',
#  'before',
#  'they',
#  'are',
#  'given',
#  'the',
#  'secret',
#  'password',
#  'to',
#  'enter',
#  'your',
#  'world',
#  'of',
#  'understanding',
#  '.',
#  'i',
#  'mean',
#  ',',
#  'showing',
#  'melissa',
#  'sagemiller',
#  'running',
#  'away',
#  'from',
#  'visions',
#  'for',
#  'about',
#  '20',
#  'minutes',
#  'throughout',
#  'the',
#  'movie',
#  'is',
#  'just',
#  'plain',
#  'lazy',
#  '!',
#  '!',
#  'okay',
#  ',',
#  'we',
#  'get',
#  'it',
#  '.',
#  '.',
#  '.',
#  'there',
#  'are',
#  'people',
#  'chasing',
#  'her',
#  'and',
#  'we',
#  'do',
#  "n't",
#  'know',
#  'who',
#  'they',
#  'are',
#  '.',
#  'do',
#  'we',
#  'really',
#  'need',
#  'to',
#  'see',
#  'it',
#  'over',
#  'and',
#  'over',
#  'again',
#  '?',
#  'how',
#  'about',
#  'giving',
#  'us',
#  'different',
#  'scenes',
#  'offering',
#  'further',
#  'insight',
#  'into',
#  'all',
#  'of',
#  'the',
#  'strangeness',
#  'going',
#  'down',
#  'in',
#  'the',
#  'movie',
#  '?',
#  'apparently',
#  ',',
#  'the',
#  'studio',
#  'took',
#  'this',
#  'film',
#  'away',
#  'from',
#  'its',
#  'director',
#  'and',
#  'chopped',
#  'it',
#  'up',
#  'themselves',
#  ',',
#  'and',
#  'it',
#  'shows',
#  '.',
#  'there',
#  'might',
#  "'ve",
#  'been',
#  'a',
#  'pretty',
#  'decent',
#  'teen',
#  'mind-fuck',
#  'movie',
#  'in',
#  'here',
#  'somewhere',
#  ',',
#  'but',
#  'i',
#  'guess',
#  '``',
#  'the',
#  'suits',
#  '``',
#  'decided',
#  'that',
#  'turning',
#  'it',
#  'into',
#  'a',
#  'music',
#  'video',
#  'with',
#  'little',
#  'edge',
#  ',',
#  'would',
#  'make',
#  'more',
#  'sense',
#  '.',
#  'the',
#  'actors',
#  'are',
#  'pretty',
#  'good',
#  'for',
#  'the',
#  'most',
#  'part',
#  ',',
#  'although',
#  'wes',
#  'bentley',
#  'just',
#  'seemed',
#  'to',
#  'be',
#  'playing',
#  'the',
#  'exact',
#  'same',
#  'character',
#  'that',
#  'he',
#  'did',
#  'in',
#  'american',
#  'beauty',
#  ',',
#  'only',
#  'in',
#  'a',
#  'new',
#  'neighborhood',
#  '.',
#  'but',
#  'my',
#  'biggest',
#  'kudos',
#  'go',
#  'out',
#  'to',
#  'sagemiller',
#  ',',
#  'who',
#  'holds',
#  'her',
#  'own',
#  'throughout',
#  'the',
#  'entire',
#  'film',
#  ',',
#  'and',
#  'actually',
#  'has',
#  'you',
#  'feeling',
#  'her',
#  'character',
#  "'s",
#  'unraveling',
#  '.',
#  'overall',
#  ',',
#  'the',
#  'film',
#  'does',
#  "n't",
#  'stick',
#  'because',
#  'it',
#  'does',
#  "n't",
#  'entertain',
#  ',',
#  'it',
#  "'s",
#  'confusing',
#  ',',
#  'it',
#  'rarely',
#  'excites',
#  'and',
#  'it',
#  'feels',
#  'pretty',
#  'redundant',
#  'for',
#  'most',
#  'of',
#  'its',
#  'runtime',
#  ',',
#  'despite',
#  'a',
#  'pretty',
#  'cool',
#  'ending',
#  'and',
#  'explanation',
#  'to',
#  'all',
#  'of',
#  'the',
#  'craziness',
#  'that',
#  'came',
#  'before',
#  'it',
#  '.',
#  'oh',
#  ',',
#  'and',
#  'by',
#  'the',
#  'way',
#  ',',
#  'this',
#  'is',
#  'not',
#  'a',
#  'horror',
#  'or',
#  'teen',
#  'slasher',
#  'flick',
#  '.',
#  '.',
#  '.',
#  'it',
#  "'s",
#  'just',
#  'packaged',
#  'to',
#  'look',
#  'that',
#  'way',
#  'because',
#  'someone',
#  'is',
#  'apparently',
#  'assuming',
#  'that',
#  'the',
#  'genre',
#  'is',
#  'still',
#  'hot',
#  'with',
#  'the',
#  'kids',
#  '.',
#  'it',
#  'also',
#  'wrapped',
#  'production',
#  'two',
#  'years',
#  'ago',
#  'and',
#  'has',
#  'been',
#  'sitting',
#  'on',
#  'the',
#  'shelves',
#  'ever',
#  'since',
#  '.',
#  'whatever',
#  '.',
#  '.',
#  '.',
#  'skip',
#  'it',
#  '!',
#  'where',
#  "'s",
#  'joblo',
#  'coming',
#  'from',
#  '?',
#  'a',
#  'nightmare',
#  'of',
#  'elm',
#  'street',
#  '3',
#  '(',
#  '7/10',
#  ')',
#  '-',
#  'blair',
#  'witch',
#  '2',
#  '(',
#  '7/10',
#  ')',
#  '-',
#  'the',
#  'crow',
#  '(',
#  '9/10',
#  ')',
#  '-',
#  'the',
#  'crow',
#  ':',
#  'salvation',
#  '(',
#  '4/10',
#  ')',
#  '-',
#  'lost',
#  'highway',
#  '(',
#  '10/10',
#  ')',
#  '-',
#  'memento',
#  '(',
#  '10/10',
#  ')',
#  '-',
#  'the',
#  'others',
#  '(',
#  '9/10',
#  ')',
#  '-',
#  'stir',
#  'of',
#  'echoes',
#  '(',
#  '8/10',
#  ')']

# %%
# Tokenise our sets of reviews; tokens remain grouped by review

negative_tokenized = [word_tokenize(review) for review in negative_reviews]
positive_tokenized = [word_tokenize(review) for review in positive_reviews]

# %%
## Q.  The texts in the movie review corpus are already in lower case, however many
##     texts found in the wild are not. How would you change the code in the cell above
##     to produce a corpus of tokenized and lower-case text?

## EXERCISE. How many tokens are there in the first negative movie review? positive?

## CHALLENGE: How many tokens are there on average in each negative movie review?

# %% [markdown]
# ## Stop Words
#
# Stop words, sometimes refered to as <i>function words</i>, include articles, prepositions, pronouns, and conjunctions among others. Although their frequencies encode information about textual features like authorship, they do not convey semantic meanings and are often removed before analysis.

# %%
# Import our list of stop words

from nltk.corpus import stopwords

# %%
# Pull up NLTK's list of English-language stop words

stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# How many stop words are in the list?

len(stopwords.words('english'))
# Out:
# 179

# %%
# NLTK has stopwords for many Western languages

stopwords.words('dutch')
# Out:
# ['de',
#  'en',
#  'van',
#  'ik',
#  'te',
#  'dat',
#  'die',
#  'in',
#  'een',
#  'hij',
#  'het',
#  'niet',
#  'zijn',
#  'is',
#  'was',
#  'op',
#  'aan',
#  'met',
#  'als',
#  'voor',
#  'had',
#  'er',
#  'maar',
#  'om',
#  'hem',
#  'dan',
#  'zou',
#  'of',
#  'wat',
#  'mijn',
#  'men',
#  'dit',
#  'zo',
#  'door',
#  'over',
#  'ze',
#  'zich',
#  'bij',
#  'ook',
#  'tot',
#  'je',
#  'mij',
#  'uit',
#  'der',
#  'daar',
#  'haar',
#  'naar',
#  'heb',
#  'hoe',
#  'heeft',
#  'hebben',
#  'deze',
#  'u',
#  'want',
#  'nog',
#  'zal',
#  'me',
#  'zij',
#  'nu',
#  'ge',
#  'geen',
#  'omdat',
#  'iets',
#  'worden',
#  'toch',
#  'al',
#  'waren',
#  'veel',
#  'meer',
#  'doen',
#  'toen',
#  'moet',
#  'ben',
#  'zonder',
#  'kan',
#  'hun',
#  'dus',
#  'alles',
#  'onder',
#  'ja',
#  'eens',
#  'hier',
#  'wie',
#  'werd',
#  'altijd',
#  'doch',
#  'wordt',
#  'wezen',
#  'kunnen',
#  'ons',
#  'zelf',
#  'tegen',
#  'na',
#  'reeds',
#  'wil',
#  'kon',
#  'niets',
#  'uw',
#  'iemand',
#  'geweest',
#  'andere']

# %%
tokenized_sentence = ['what', 'is', 'the', 'air-speed', 'velocity', 'of', 'an', 'unladen', 'swallow']

# %%
# Remove stopwords from tokenised review

for word in tokenized_sentence:
    if word not in stopwords.words('english'):
        print(word)
# Out:
# air-speed
# velocity
# unladen
# swallow

# %%
# But what if we have more than one review at a time?

two_sentences = [['what', 'is', 'the', 'air-speed', 'velocity', 'of', 'an', 'unladen', 'swallow'],\
               ['what', 'do', 'you', 'mean', 'african', 'or', 'european']]

# %%
# Use a nested for-loop!

for sentence in two_sentences:
    for word in sentence:
        if word not in stopwords.words('english'):
            print(word)
# Out:
# air-speed
# velocity
# unladen
# swallow
# mean
# african
# european

# %%
# The example sentences were short so it's hard to tell, but looking up
# whether a word is 'in' a list takes a pretty long time

# We can improve the speed of our task by converting the list to a set!

stopword_set = set(stopwords.words('english'))

# %%
# Inspect

stopword_set
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# And we can remove the stop words from our movie reviews

negative_no_stops = [[word for word in review if word not in stopword_set] for review in negative_tokenized]
positive_no_stops = [[word for word in review if word not in stopword_set] for review in positive_tokenized]

# %%
## Q.  Stop words are typically the most frequent words in a language, yet do not convey semantic meaning.
##     Does this make sense based on the words in NLTK's list of English stop words?
##     What about other languages with which you are familar?

stopword_languages = ['danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian',\
                      'norwegian', 'portuguese', 'russian', 'spanish', 'swedish', 'turkish']

## EXERCISE. How many tokens did we remove from the first negative review in total? What percent were removed?

## CHALLENGE.  Stop words are often instrumental in language detection for unknown texts.
##             How might you write a program to do this?

# %% [markdown]
# ## Lemmatise
#
# Lemmatisation transforms an inflected word into its root. For nouns, this often converts plural form to singular. For verbs, this often produces the infinitive. So for example, both 'digging' and 'dug' are transformed to it's base form, 'dig'.
#
# NLTK's lemmatisation function assumes that all words are nouns by default and leaves most non-nouns untouched!
#
# <h3>WordNet Abbreviations</h3>
# <table align='left'>
# <tr><td>Noun</td><td>'n'</td><td>wordnet.NOUN</td></tr>
# <tr><td>Verb</td><td>'v'</td><td>wordnet.VERB</td></tr>
# <tr><td>Adjective</td><td>'a'</td><td>wordnet.ADJ</td></tr>
# <tr><td>Adverb</td><td>'r'</td><td>wordnet.ADV</td></tr>
# </table>

# %%
# Import NLTK's lemmatiser

from nltk.stem import WordNetLemmatizer

# %%
# Initialise the lemmatiser and assign it to a variable

wnl = WordNetLemmatizer()

# %%
# The lemmatisation is called as a method: .lemmatize()

wnl.lemmatize('artefacts')
# Out:
# 'artefact'

# %%
# Doesn't seem to work properly on 'digging' because 'wnl' assumes it is seeing a noun

wnl.lemmatize('digging')
# Out:
# 'digging'

# %%
# Fortunately we can pass in a label for a different part of speech
# Perhaps one might use this along with a POS tagger!

wnl.lemmatize('digging', pos='v')
# Out:
# 'dig'

# %%
# A new list of tokens

famous_sketch = ['ministry','of', 'silly', 'walks']

# %%
# Use a for-loop to lemmatise each word sequentially

for word in famous_sketch:
    print(wnl.lemmatize(word))
# Out:
# ministry
# of
# silly
# walk

# %%
# Now, two lists of tokens

two_sketches = [['ministry','of', 'silly', 'walks'],['musical','mice']]

# %%
# As a nested loop

for sketch in two_sketches:
    for word in sketch:
        print(wnl.lemmatize(word))
# Out:
# ministry
# of
# silly
# walk
# musical
# mouse

# %%
# Let's lemmatise the nouns in our movie reviews

negative_lemmatized = [[wnl.lemmatize(word) for word in review] for review in negative_no_stops]
positive_lemmatized = [[wnl.lemmatize(word) for word in review] for review in positive_no_stops]

# %%
## EXERCISE. Lemmatise the list of plural nouns below

plural_nouns = ['parrots', 'witches', 'volcanoes', 'soliloquies', 'cherries', 'addenda', \
                'baths', 'knives', 'oxen', 'lice', 'brethren', 'alumni', 'alumnae', 'matrices']

## CHALLENGE: Use the part-of-speech tagger we looked at in the previous module and include
##            a POS argument while lemmatising the following sentence.

brave_sir_robin = "When danger reared its ugly head, he bravely turned his tail and fled!"

# %% [markdown]
# ## Minimum Document Frequency
#
# Intuitively, not all words in the corpus will convey the same amount of information about whether a movie review is positive or negative or whether a poem is a haiku. At the extreme, if a word appears in just a single text out of thousands, it doesn't tell us much either way about whether that word is associated with a category. By removing infrequent terms from our model, we can also save computational time.
#
# When we measure document frequency, we do not need to know how many times a token appears in a text. We simply need to know which tokens appear in each. Python has an easy, built-in data type that that tells us the unique elements appearing in a list: <i>set</i>. As a data-type, a set is like a list but it does not retain information about the order of elements. Also, it is very effient when we want to check 'if' a particular element is contained 'in' a group of words.
#
# In order to count the document frequency for each word in the corpus, we will produce a set of unique words for each text. Then we will pull out each word from each set and put these into a single list. Words belonging to multiple sets will appear multiple times; words belonging to just a single set will appear only once. Finally, we will use the <i>Counter</i> to tally how many times each word appears in the term-document frequency list.

# %% [markdown]
# ### Set: Function/Data-Type

# %%
# Here's a text that reuses many of its words

gertrude_stein = ['rose','is', 'a', 'rose', 'is', 'a', 'rose', 'is', 'a', 'rose', '.']

# %%
# Return a 'set' of the unique tokens in the text
# A set is like a list but does not retain information about order, and does not include duplicate items

set(gertrude_stein)
# Out:
# {'.', 'a', 'is', 'rose'}

# %%
# The size of the set is much smaller than the text itself

len(gertrude_stein), len(set(gertrude_stein))
# Out:
# (11, 4)

# %%
# Produce a set of unique tokens contained in each review

negative_sets = [set(review) for review in negative_lemmatized]
positive_sets = [set(review) for review in positive_lemmatized]

# %% [markdown]
# ### Document Frequency

# %%
# We want frequencies for the whole corpus, so we'll put our sets of words together now

all_sets = negative_sets + positive_sets

# %%
# Check that we got them all

len(negative_sets), len(positive_sets), len(all_sets)
# Out:
# (1000, 1000, 2000)

# %%
# And we'll pull out the words from each review set
# This produces a list in which each token appears as many times as the number documents to which it belongs

term_document_frequency_list = [word for review in all_sets for word in review]

# %%
# We want to count the number of times each token appears, so we'll use 'Counter'

from collections import Counter

tdf_counts = Counter(term_document_frequency_list)

# %%
# Inspect

tdf_counts
# Out:
# Counter({'somewhere': 120,
#          'applaud': 10,
#          'watch': 489,
#          '(': 1900,
#          'decided': 97,
#          'clue': 68,
#          'fantasy': 101,
#          'slasher': 47,
#          'life': 900,
#          'really': 867,
#          'kid': 318,
#          'director': 868,
#          'throughout': 261,
#          'apparently': 183,
#          'hold': 185,
#          'terribly': 53,
#          'always': 433,
#          'also': 1070,
#          'stir': 21,
#          'street': 159,
#          'church': 46,
#          'party': 125,
#          '&': 166,
#          'downshift': 2,
#          'got': 365,
#          'unraveling': 2,
#          'generally': 98,
#          'thing': 959,
#          'new': 758,
#          'u': 703,
#          'plot': 893,
#          'arrow': 22,
#          'showing': 138,
#          'seems': 686,
#          'accident': 83,
#          'mind': 389,
#          '.': 2000,
#          'giving': 192,
#          'bentley': 5,
#          'deal': 241,
#          '``': 1540,
#          'five': 199,
#          'need': 427,
#          'back': 724,
#          'thrilling': 42,
#          'go': 1036,
#          'sad': 97,
#          'running': 270,
#          'excites': 2,
#          '20': 72,
#          'happen': 185,
#          'chase': 157,
#          'want': 713,
#          'sorta': 9,
#          'personally': 43,
#          'fed': 31,
#          'two': 1024,
#          'still': 702,
#          'would': 1172,
#          'salvation': 12,
#          'package': 29,
#          'bit': 455,
#          'elm': 11,
#          'character': 1431,
#          'dy': 94,
#          'sense': 408,
#          'every': 672,
#          'neighborhood': 19,
#          'since': 558,
#          'kind': 433,
#          'see': 1014,
#          'rarely': 95,
#          'attempt': 378,
#          'dead': 278,
#          'main': 331,
#          'obviously': 206,
#          'little': 916,
#          'offering': 40,
#          'folk': 91,
#          'disappearance': 8,
#          'entire': 328,
#          'took': 145,
#          'lost': 285,
#          'beauty': 95,
#          'horror': 230,
#          'neat': 31,
#          'edge': 90,
#          'unravel': 9,
#          'packaged': 3,
#          '9/10': 17,
#          'exact': 59,
#          'chopped': 4,
#          'teen': 108,
#          'redundant': 14,
#          'audience': 726,
#          'explained': 60,
#          'bottom': 77,
#          'ending': 304,
#          'write': 97,
#          '2': 238,
#          'people': 855,
#          'studio': 135,
#          'minute': 551,
#          'big': 610,
#          'guess': 196,
#          'going': 628,
#          'coming': 229,
#          'even': 1291,
#          'well': 992,
#          'scene': 1165,
#          'confusing': 80,
#          'mold': 18,
#          'get': 1317,
#          'others': 251,
#          'snag': 3,
#          'touch': 145,
#          'critique': 62,
#          'witch': 54,
#          'type': 180,
#          'given': 402,
#          'someone': 333,
#          'like': 1488,
#          'cool': 151,
#          'biggest': 135,
#          'world': 595,
#          'part': 630,
#          'actually': 574,
#          'executed': 42,
#          'know': 883,
#          'explanation': 64,
#          'playing': 294,
#          'shelf': 24,
#          'nightmare': 64,
#          'bad': 763,
#          'wrapped': 37,
#          "'s": 1949,
#          'sagemiller': 2,
#          'start': 486,
#          'video': 239,
#          'one': 1765,
#          '4/10': 10,
#          'way': 1074,
#          'make': 1310,
#          'harder': 31,
#          'good': 1154,
#          'completely': 353,
#          'mind-fuck': 1,
#          'half-way': 6,
#          'point': 580,
#          'sure': 412,
#          'plain': 74,
#          'might': 494,
#          'movie': 1643,
#          ',': 1997,
#          'entertaining': 258,
#          'mean': 328,
#          'password': 2,
#          'jumbled': 11,
#          'film': 1793,
#          'taken': 200,
#          'vision': 80,
#          'insight': 58,
#          'guy': 537,
#          'american': 341,
#          'strangeness': 5,
#          'hide': 55,
#          'problem': 505,
#          'different': 342,
#          'review': 292,
#          'secret': 172,
#          'came': 168,
#          'drink': 38,
#          'highway': 19,
#          'hot': 98,
#          'craziness': 3,
#          'enter': 64,
#          '10/10': 12,
#          'feeling': 248,
#          'ton': 35,
#          'decent': 149,
#          'find': 758,
#          'strange': 149,
#          'meantime': 19,
#          'figured': 28,
#          'actor': 788,
#          '3': 118,
#          'away': 512,
#          'girlfriend': 177,
#          'blair': 44,
#          'present': 217,
#          'drive': 124,
#          'whatever': 129,
#          'music': 310,
#          'line': 529,
#          'ever': 550,
#          ')': 1901,
#          'lazy': 31,
#          'head': 360,
#          'memento': 4,
#          'normal': 89,
#          'although': 528,
#          'engaging': 72,
#          '!': 663,
#          'assuming': 15,
#          'couple': 330,
#          'flick': 209,
#          'simply': 328,
#          'melissa': 8,
#          'making': 466,
#          'correctly': 15,
#          'trying': 441,
#          'despite': 279,
#          'genre': 216,
#          'crow': 24,
#          '8/10': 30,
#          'turning': 77,
#          'ago': 178,
#          'feel': 509,
#          'weird': 75,
#          'look': 822,
#          'oh': 172,
#          'joblo': 26,
#          ':': 1243,
#          'sitting': 87,
#          '-': 460,
#          'concept': 113,
#          'suit': 96,
#          'generation': 83,
#          'pretty': 392,
#          'show': 694,
#          'dig': 28,
#          'okay': 106,
#          '7/10': 29,
#          'give': 720,
#          'mess': 149,
#          '?': 1228,
#          'dream': 193,
#          'member': 232,
#          'skip': 45,
#          'overall': 145,
#          'break': 211,
#          'looooot': 1,
#          "n't": 1669,
#          'echo': 31,
#          'seem': 446,
#          'entertain': 51,
#          "'ve": 550,
#          'runtime': 7,
#          'production': 256,
#          'understanding': 54,
#          'year': 947,
#          'apparition': 7,
#          'continues': 79,
#          'chasing': 33,
#          'wes': 35,
#          'kudos': 19,
#          'idea': 390,
#          'stick': 85,
#          'final': 296,
#          'seemed': 177,
#          'kick': 68,
#          'come': 967,
#          'work': 863,
#          'drunkenly': 2,
#          'stan': 9,
#          'occasional': 60,
#          'acting': 528,
#          'middle': 174,
#          'body': 247,
#          'real': 586,
#          'sunken': 2,
#          'bringing': 71,
#          'h20': 7,
#          'stumbling': 15,
#          'russian': 52,
#          'mir': 6,
#          'around': 677,
#          'y2k': 4,
#          'donald': 28,
#          'shot': 371,
#          'bastard': 39,
#          'picking': 24,
#          'within': 179,
#          'tech': 11,
#          'hey': 64,
#          'design': 86,
#          'happy': 176,
#          'much': 1128,
#          'flashy': 39,
#          'baldwin': 42,
#          'sequence': 456,
#          "'re": 607,
#          'power': 224,
#          'brother': 255,
#          'empty': 56,
#          'origin': 18,
#          'quick': 118,
#          'let': 395,
#          'regarding': 30,
#          'halloween': 40,
#          'starring': 159,
#          'virus': 23,
#          'substance': 69,
#          'average': 94,
#          'cgi': 40,
#          'winston': 4,
#          'ship': 112,
#          'lee': 150,
#          'course': 496,
#          'action': 593,
#          'tugboat': 2,
#          'hit': 297,
#          'wasted': 112,
#          'damn': 77,
#          'curtis': 23,
#          'william': 139,
#          'story': 1098,
#          'across': 195,
#          'time': 1383,
#          'star': 633,
#          'otherwise': 143,
#          'gore': 78,
#          'flash': 65,
#          'schnazzy': 1,
#          'sutherland': 21,
#          'nowhere': 85,
#          'jamie': 32,
#          'likely': 148,
#          'robot': 42,
#          'another': 794,
#          'crew': 135,
#          'bug': 52,
#          'turn': 565,
#          'deserted': 20,
#          'brain': 94,
#          'pink': 20,
#          'certainly': 294,
#          'juvenile': 21,
#          'fifteen': 55,
#          'rash': 7,
#          'blowing': 22,
#          'squad': 17,
#          'unfortunately': 329,
#          'escape': 164,
#          'clear': 164,
#          'appears': 211,
#          'epps': 8,
#          'play': 808,
#          'clich': 66,
#          'deliver': 88,
#          'indication': 11,
#          'extremely': 210,
#          'avoid': 87,
#          'basing': 4,
#          'cast': 561,
#          'transfer': 19,
#          'complete': 178,
#          'stuff': 180,
#          'cop': 153,
#          'questionable': 18,
#          'hip': 41,
#          'considers': 18,
#          'span': 25,
#          'teenage': 82,
#          'wooden': 47,
#          'half': 294,
#          'car': 254,
#          'becomes': 414,
#          'r': 139,
#          'screen': 514,
#          'described': 55,
#          'ad': 70,
#          'worth': 269,
#          'predictable': 157,
#          'literally': 101,
#          'wo': 233,
#          'outfit': 32,
#          'towards': 161,
#          'apparent': 95,
#          'based': 326,
#          'enough': 664,
#          'hard': 384,
#          'rating': 126,
#          'hour-long': 3,
#          'everything': 399,
#          'however': 655,
#          'content': 77,
#          'missing': 105,
#          'dollar': 115,
#          'indiglo': 1,
#          'instead': 455,
#          'number': 213,
#          'fact': 611,
#          'teen-flicks': 1,
#          'older': 88,
#          'best': 837,
#          'giovanni': 11,
#          'especially': 374,
#          'care': 301,
#          'omar': 12,
#          'stolen': 51,
#          'reformed': 6,
#          'mod': 10,
#          'timex': 1,
#          'tale': 199,
#          'dane': 17,
#          'element': 298,
#          'suspicion': 22,
#          'nice': 263,
#          'recycled': 24,
#          'progress': 73,
#          'already': 258,
#          'cost': 45,
#          'seeing': 291,
#          'dialogue': 400,
#          'three': 424,
#          'spoon-fed': 3,
#          'single': 197,
#          'thankful': 7,
#          'immediately': 145,
#          'hair': 95,
#          'seen': 629,
#          'occupying': 5,
#          'jeopardy': 12,
#          'six': 106,
#          'stretched': 18,
#          'slick': 39,
#          'finger': 43,
#          'remembers': 7,
#          'cross': 69,
#          'police': 183,
#          'cash': 73,
#          'claire': 33,
#          'telling': 114,
#          'save': 260,
#          'unscathed': 8,
#          'employ': 31,
#          'onto': 112,
#          'resident': 32,
#          'cut': 188,
#          'bordering': 6,
#          'information': 79,
#          'hour': 398,
#          'counted': 13,
#          'name': 373,
#          'nothing': 590,
#          'hand': 373,
#          'matter': 321,
#          'spending': 46,
#          'late': 210,
#          '1960': 20,
#          'checked': 6,
#          'tell': 447,
#          'sometimes': 205,
#          'costume': 98,
#          'crazy': 74,
#          'first': 1020,
#          'viewer': 295,
#          'invention': 15,
#          'awful': 120,
#          'memorable': 127,
#          'cute': 100,
#          'judging': 31,
#          'clothes': 48,
#          'watching': 411,
#          'sound': 296,
#          'ribisi': 11,
#          'hero': 250,
#          'wisdom': 32,
#          'convoluted': 29,
#          "'ll": 419,
#          'written': 314,
#          'evidence': 60,
#          'looking': 344,
#          'target': 95,
#          'bored': 77,
#          'apart': 102,
#          'criminal': 90,
#          'young': 504,
#          'nobody': 81,
#          'wrong': 311,
#          'relatively': 65,
#          'jaded': 12,
#          'spectacular': 74,
#          'ultimately': 139,
#          'poorly': 78,
#          'geared': 13,
#          'quickly': 217,
#          'soundtrack': 127,
#          'man': 794,
#          'undercover': 25,
#          "'": 773,
#          'television': 160,
#          'justify': 21,
#          'mindset': 11,
#          'instantly': 38,
#          'bronson': 9,
#          'recent': 194,
#          'promising': 50,
#          'specific': 38,
#          'fan': 255,
#          'arrival': 37,
#          'error': 19,
#          '1997': 99,
#          'challenger': 2,
#          'revolves': 51,
#          'two-headed': 3,
#          'must': 477,
#          'warner': 38,
#          'magical': 47,
#          'hands-down': 4,
#          'palate': 4,
#          '--': 561,
#          'rank': 34,
#          'saturday': 48,
#          'jane': 47,
#          'hydra': 2,
#          'recall': 62,
#          'personality': 125,
#          'arthur': 25,
#          'child': 365,
#          'keeping': 81,
#          'jessalyn': 1,
#          'colorful': 46,
#          'seymour': 7,
#          'lack': 280,
#          'rickles': 4,
#          'singer': 72,
#          'loses': 79,
#          'timberland-dweller': 1,
#          'sign': 121,
#          'century': 98,
#          'showmanship': 3,
#          'rest': 373,
#          'sexist': 13,
#          'case': 334,
#          'ruber': 1,
#          'reason': 460,
#          'comedy': 510,
#          'cloying': 5,
#          'pocahontas': 7,
#          'gilsig': 1,
#          'crown': 14,
#          'forest': 39,
#          'awfully': 25,
#          'shtick': 13,
#          'free-spirited': 6,
#          'sharing': 13,
#          'animation': 70,
#          'climb': 20,
#          'king': 139,
#          'table': 67,
#          'member-gone-bad': 1,
#          'something': 720,
#          '20th': 25,
#          'run-in': 5,
#          'follow': 148,
#          'footage': 79,
#          'compare': 40,
#          'accidentally': 56,
#          'line-up': 5,
#          'eric': 48,
#          'angry': 62,
#          'nearly': 259,
#          'probably': 424,
#          'sword': 30,
#          'belated': 2,
#          'kingdom': 15,
#          'high': 347,
#          'thrilled': 15,
#          'dion': 1,
#          'hunky': 10,
#          'voiced': 34,
#          'herc': 2,
#          'strain': 24,
#          'feature-length': 13,
#          'ex-round': 1,
#          'garrett': 3,
#          'clout': 9,
#          'fox': 63,
#          'able': 290,
#          'remotely': 47,
#          'providing': 43,
#          "'d": 309,
#          'forgettable': 29,
#          'magic': 75,
#          'paired': 8,
#          'worried': 25,
#          'jaleel': 1,
#          'anastasia': 8,
#          'mediocre': 70,
#          'footstep': 17,
#          'computerized': 4,
#          'end': 869,
#          'nicely': 91,
#          'warlord': 3,
#          'throne': 15,
#          'camelot': 4,
#          'pinchot': 2,
#          'mouse': 35,
#          'flawed': 45,
#          'enthusiastic': 18,
#          'morning': 64,
#          'differentiates': 2,
#          'fully-animated': 1,
#          'kayley': 1,
#          'celine': 4,
#          'ogre': 10,
#          'last': 600,
#          'dragon': 33,
#          'stink': 21,
#          'father': 326,
#          'round': 39,
#          'none': 208,
#          'oldman': 15,
#          'learn': 154,
#          'song': 144,
#          'aside': 118,
#          'knight': 40,
#          'beat': 88,
#          'fighter': 37,
#          'essential': 32,
#          'expected': 125,
#          'white': 198,
#          'disney': 90,
#          'adult': 152,
#          'chance': 208,
#          "'m": 406,
#          'though': 638,
#          'idle': 17,
#          'grievous': 3,
#          'cartoon': 65,
#          'contest': 21,
#          'elwes': 5,
#          'musical': 100,
#          "early-'90s": 1,
#          'carey': 5,
#          'evil': 259,
#          'pulse': 16,
#          'dull': 115,
#          'side': 292,
#          'voice': 191,
#          'pure': 82,
#          'realized': 75,
#          'tgif': 2,
#          'gary': 63,
#          'empire': 29,
#          'long': 588,
#          'interesting': 479,
#          'steal': 118,
#          'race': 98,
#          'piece': 279,
#          'out-bland': 1,
#          'battle': 171,
#          'talent': 263,
#          'adventure': 112,
#          'help': 480,
#          'hercules': 12,
#          'score': 188,
#          'fall': 397,
#          'moment': 543,
#          'early-teen': 1,
#          'dangerous': 66,
#          'booby-trapped': 1,
#          'balki': 1,
#          'medieval': 12,
#          'prove': 100,
#          'daughter': 208,
#          'lively': 28,
#          'urkel': 2,
#          'tie': 45,
#          'least': 530,
#          'quest': 53,
#          'arguing': 15,
#          'excalibur': 3,
#          'subpar': 3,
#          'win': 138,
#          'loss': 51,
#          'blind': 39,
#          'poorly-integrated': 1,
#          'bros': 22,
#          'stalker': 5,
#          'produce': 52,
#          'found': 328,
#          'adequate': 35,
#          '1990s': 19,
#          'comment': 78,
#          'collect': 21,
#          'try': 516,
#          'quite': 473,
#          'presence': 167,
#          'endless': 52,
#          'strip': 44,
#          'picture': 462,
#          'proliferation': 3,
#          'become': 411,
#          'receives': 29,
#          'invariably': 6,
#          'front': 129,
#          'potentially': 37,
#          'implied': 8,
#          'proceed': 25,
#          'mostly': 215,
#          'inevitable': 63,
#          'love': 681,
#          'direct-to-video': 9,
#          'heroine': 52,
#          'instance': 94,
#          'shower': 33,
#          'psycho': 42,
#          'derivative': 22,
#          'toward': 87,
#          'late-night': 7,
#          'stalk': 11,
#          'allowing': 41,
#          'place': 530,
#          'brings': 185,
#          'kill': 268,
#          'episode': 114,
#          'slightly': 134,
#          'played': 547,
#          'all-time': 15,
#          'cliche': 119,
#          'disbelief': 43,
#          'stalked': 11,
#          'serve': 70,
#          'unsuccessfully': 9,
#          'left': 364,
#          'inside': 148,
#          'ex-husband': 7,
#          'gleason': 2,
#          'mother': 267,
#          'ponders': 7,
#          'event': 228,
#          'open': 283,
#          'provide': 118,
#          'parked': 4,
#          'underwood': 9,
#          'independent': 40,
#          'several': 334,
#          'meant': 79,
#          'rejected': 18,
#          'brooke': 6,
#          'typically': 24,
#          'equally': 100,
#          'somewhat': 164,
#          'obvious': 251,
#          'demand': 55,
#          'jay': 43,
#          'doomed': 28,
#          'plan': 207,
#          'men': 309,
#          'suspense': 146,
#          'daylight': 16,
#          'door': 120,
#          'opening': 248,
#          'fledgling': 7,
#          'together': 425,
#          'murder': 211,
#          'offensive': 58,
#          'desperate': 90,
#          'statistic': 1,
#          'answer': 137,
#          'living': 195,
#          'exception': 118,
#          'gain': 52,
#          'never': 847,
#          "d'abo": 2,
#          'proceeds': 27,
#          'synopsis': 67,
#          'excuse': 75,
#          'include': 104,
#          'require': 34,
#          'ex-lover': 3,
#          'mood': 88,
#          'seemingly': 110,
#          'daniel': 57,
#          'entry': 48,
#          'home': 409,
#          'question': 348,
#          'string': 49,
#          'attempting': 53,
#          'undergoing': 3,
#          'ex-wife': 11,
#          'manages': 222,
#          'example': 284,
#          'unstable': 15,
#          'ditzy': 13,
#          'called': 293,
#          'return': 232,
#          'bar': 75,
#          'else': 329,
#          'ob': 7,
#          'intelligence': 110,
#          'favor': 58,
#          'close': 206,
#          'shown': 115,
#          'cable': 39,
#          'special': 362,
#          'waver': 2,
#          'showdown': 33,
#          'implicitly': 3,
#          'many': 789,
#          'industry': 74,
#          'somehow': 174,
#          'begin': 455,
#          'norm': 21,
#          'cause': 133,
#          'strong': 218,
#          'enters': 32,
#          'inexpensive': 3,
#          'watched': 75,
#          'rather': 473,
#          'conclusion': 121,
#          'toolbox': 1,
#          'melodrama': 34,
#          'validity': 2,
#          'overdoes': 4,
#          'required': 49,
#          'contrary': 26,
#          'highly': 117,
#          'thriller': 220,
#          'vehicle': 81,
#          'set': 590,
#          'respect': 96,
#          'uniformly': 15,
#          'serious-sounding': 1,
#          'suspension': 16,
#          'wanders': 29,
#          'daryl': 13,
#          'effect': 448,
#          'victim': 141,
#          'elaborate': 59,
#          'yet': 473,
#          'bond': 86,
#          'chick': 34,
#          'house': 261,
#          'anything': 499,
#          'frequent': 35,
#          'interspersed': 5,
#          'guesswork': 1,
#          'due': 173,
#          'state': 201,
#          'business-owner': 1,
#          'incredible': 88,
#          ';': 757,
#          'affair': 92,
#          'boring': 217,
#          'stake': 23,
#          'mentally': 29,
#          'leave': 198,
#          'credit': 281,
#          'whole': 391,
#          'turkey': 37,
#          'brief': 124,
#          'title': 270,
#          'word': 349,
#          'dust': 19,
#          'spurned-psychos-getting-their-revenge': 1,
#          'boy': 296,
#          'restauranteur': 1,
#          'psycho-in-love': 1,
#          'pet': 36,
#          'maryam': 1,
#          'fatal': 30,
#          'woo': 44,
#          'ensure': 15,
#          'follows': 158,
#          'murdered': 50,
#          'either': 329,
#          'decides': 175,
#          'take': 983,
#          'stable': 14,
#          'nudity': 59,
#          'psychotherapy': 2,
#          'midnight': 29,
#          'lead': 410,
#          'contrived': 72,
#          'cat': 54,
#          'woman': 518,
#          'may': 580,
#          'pas': 91,
#          'oblivious': 15,
#          'theatrical': 44,
#          'spout': 6,
#          'category': 47,
#          'survives': 20,
#          'creepy': 77,
#          'viewed': 43,
#          'rated': 107,
#          'narrator': 30,
#          'snapshot': 5,
#          'use': 328,
#          'right': 600,
#          'danger': 65,
#          'darkness': 44,
#          'novel': 183,
#          'release': 186,
#          'sucker': 11,
#          'moderately': 15,
#          'alien': 168,
#          'savage': 30,
#          'essentially': 57,
#          'tone': 137,
#          'except': 196,
#          'manner': 105,
#          'following': 165,
#          'capsule': 46,
#          'homage': 52,
#          'panned': 11,
#          'taking': 203,
#          'supposedly': 75,
#          'automatic': 9,
#          'rushing': 8,
#          'wife': 392,
#          'desolation': 5,
#          'powerful': 146,
#          'terror': 48,
#          'fit': 108,
#          'decapitation': 5,
#          'filmed': 96,
#          'rundown': 3,
#          'changed': 72,
#          'imagination': 76,
#          '-4': 30,
#          'walk': 144,
#          'advance': 46,
#          'sue': 16,
#          'train': 85,
#          'stretch': 53,
#          '4': 70,
#          'basic': 115,
#          'belief': 115,
#          'classic': 259,
#          'tacky': 9,
#          'beyond': 161,
#          '10': 131,
#          'facing': 22,
#          '13': 37,
#          'scary': 106,
#          'control': 126,
#          'weapon': 85,
#          'human': 331,
#          'yellow': 17,
#          'full': 268,
#          'easier': 39,
#          'expect': 187,
#          'rate': 70,
#          'wilson': 42,
#          'mining': 21,
#          'previous': 155,
#          'female': 131,
#          'entirely': 114,
#          'position': 72,
#          'told': 182,
#          'mar': 45,
#          '0': 33,
#          'reviewer': 31,
#          'carpenter': 25,
#          'face': 331,
#          'sudden': 52,
#          'custody': 18,
#          'liked': 136,
#          'accused': 36,
#          'precinct': 3,
#          'buildup': 10,
#          'lot': 577,
#          'twice': 90,
#          'stagnated': 1,
#          'view': 152,
#          'surface': 63,
#          'red': 124,
#          'great': 696,
#          'ghost': 49,
#          'surprising': 91,
#          'low-powered': 1,
#          'unimpressive': 7,
#          'jump': 98,
#          'minor': 123,
#          'earth-normal': 1,
#          'admittedly': 36,
#          'yes': 214,
#          'advanced': 22,
#          '2176': 3,
#          'colony': 18,
#          'gravity': 14,
#          'ten': 140,
#          'replaced': 48,
#          'hoodlum': 8,
#          'building': 116,
#          'terraformed': 1,
#          'assault': 34,
#          'thinking': 157,
#          'science': 116,
#          'wannabe': 35,
#          'planet': 135,
#          'williams': 115,
#          'expert': 47,
#          'heavy': 101,
#          'gear': 23,
#          ...})

# %%
# Let's refresh ourselves on Counter's methods

tdf_counts.keys()
# Out:
# dict_keys(['somewhere', 'applaud', 'watch', '(', 'decided', 'clue', 'fantasy', 'slasher', 'life', 'really', 'kid', 'director', 'throughout', 'apparently', 'hold', 'terribly', 'always', 'also', 'stir', 'street', 'church', 'party', '&', 'downshift', 'got', 'unraveling', 'generally', 'thing', 'new', 'u', 'plot', 'arrow', 'showing', 'seems', 'accident', 'mind', '.', 'giving', 'bentley', 'deal', '``', 'five', 'need', 'back', 'thrilling', 'go', 'sad', 'running', 'excites', '20', 'happen', 'chase', 'want', 'sorta', 'personally', 'fed', 'two', 'still', 'would', 'salvation', 'package', 'bit', 'elm', 'character', 'dy', 'sense', 'every', 'neighborhood', 'since', 'kind', 'see', 'rarely', 'attempt', 'dead', 'main', 'obviously', 'little', 'offering', 'folk', 'disappearance', 'entire', 'took', 'lost', 'beauty', 'horror', 'neat', 'edge', 'unravel', 'packaged', '9/10', 'exact', 'chopped', 'teen', 'redundant', 'audience', 'explained', 'bottom', 'ending', 'write', '2', 'people', 'studio', 'minute', 'big', 'guess', 'going', 'coming', 'even', 'well', 'scene', 'confusing', 'mold', 'get', 'others', 'snag', 'touch', 'critique', 'witch', 'type', 'given', 'someone', 'like', 'cool', 'biggest', 'world', 'part', 'actually', 'executed', 'know', 'explanation', 'playing', 'shelf', 'nightmare', 'bad', 'wrapped', "'s", 'sagemiller', 'start', 'video', 'one', '4/10', 'way', 'make', 'harder', 'good', 'completely', 'mind-fuck', 'half-way', 'point', 'sure', 'plain', 'might', 'movie', ',', 'entertaining', 'mean', 'password', 'jumbled', 'film', 'taken', 'vision', 'insight', 'guy', 'american', 'strangeness', 'hide', 'problem', 'different', 'review', 'secret', 'came', 'drink', 'highway', 'hot', 'craziness', 'enter', '10/10', 'feeling', 'ton', 'decent', 'find', 'strange', 'meantime', 'figured', 'actor', '3', 'away', 'girlfriend', 'blair', 'present', 'drive', 'whatever', 'music', 'line', 'ever', ')', 'lazy', 'head', 'memento', 'normal', 'although', 'engaging', '!', 'assuming', 'couple', 'flick', 'simply', 'melissa', 'making', 'correctly', 'trying', 'despite', 'genre', 'crow', '8/10', 'turning', 'ago', 'feel', 'weird', 'look', 'oh', 'joblo', ':', 'sitting', '-', 'concept', 'suit', 'generation', 'pretty', 'show', 'dig', 'okay', '7/10', 'give', 'mess', '?', 'dream', 'member', 'skip', 'overall', 'break', 'looooot', "n't", 'echo', 'seem', 'entertain', "'ve", 'runtime', 'production', 'understanding', 'year', 'apparition', 'continues', 'chasing', 'wes', 'kudos', 'idea', 'stick', 'final', 'seemed', 'kick', 'come', 'work', 'drunkenly', 'stan', 'occasional', 'acting', 'middle', 'body', 'real', 'sunken', 'bringing', 'h20', 'stumbling', 'russian', 'mir', 'around', 'y2k', 'donald', 'shot', 'bastard', 'picking', 'within', 'tech', 'hey', 'design', 'happy', 'much', 'flashy', 'baldwin', 'sequence', "'re", 'power', 'brother', 'empty', 'origin', 'quick', 'let', 'regarding', 'halloween', 'starring', 'virus', 'substance', 'average', 'cgi', 'winston', 'ship', 'lee', 'course', 'action', 'tugboat', 'hit', 'wasted', 'damn', 'curtis', 'william', 'story', 'across', 'time', 'star', 'otherwise', 'gore', 'flash', 'schnazzy', 'sutherland', 'nowhere', 'jamie', 'likely', 'robot', 'another', 'crew', 'bug', 'turn', 'deserted', 'brain', 'pink', 'certainly', 'juvenile', 'fifteen', 'rash', 'blowing', 'squad', 'unfortunately', 'escape', 'clear', 'appears', 'epps', 'play', 'clich', 'deliver', 'indication', 'extremely', 'avoid', 'basing', 'cast', 'transfer', 'complete', 'stuff', 'cop', 'questionable', 'hip', 'considers', 'span', 'teenage', 'wooden', 'half', 'car', 'becomes', 'r', 'screen', 'described', 'ad', 'worth', 'predictable', 'literally', 'wo', 'outfit', 'towards', 'apparent', 'based', 'enough', 'hard', 'rating', 'hour-long', 'everything', 'however', 'content', 'missing', 'dollar', 'indiglo', 'instead', 'number', 'fact', 'teen-flicks', 'older', 'best', 'giovanni', 'especially', 'care', 'omar', 'stolen', 'reformed', 'mod', 'timex', 'tale', 'dane', 'element', 'suspicion', 'nice', 'recycled', 'progress', 'al ...

# %%
# How many reviews refer to the larger film industry?

tdf_counts['hollywood']
# Out:
# 385

# %%
# Produce a list of words whose tdf-count is greater than 1

more_than_once = [key for key in tdf_counts.keys() if tdf_counts[key]>1]

# %%
# Inspect

more_than_once
# Out:
# ['somewhere',
#  'applaud',
#  'watch',
#  '(',
#  'decided',
#  'clue',
#  'fantasy',
#  'slasher',
#  'life',
#  'really',
#  'kid',
#  'director',
#  'throughout',
#  'apparently',
#  'hold',
#  'terribly',
#  'always',
#  'also',
#  'stir',
#  'street',
#  'church',
#  'party',
#  '&',
#  'downshift',
#  'got',
#  'unraveling',
#  'generally',
#  'thing',
#  'new',
#  'u',
#  'plot',
#  'arrow',
#  'showing',
#  'seems',
#  'accident',
#  'mind',
#  '.',
#  'giving',
#  'bentley',
#  'deal',
#  '``',
#  'five',
#  'need',
#  'back',
#  'thrilling',
#  'go',
#  'sad',
#  'running',
#  'excites',
#  '20',
#  'happen',
#  'chase',
#  'want',
#  'sorta',
#  'personally',
#  'fed',
#  'two',
#  'still',
#  'would',
#  'salvation',
#  'package',
#  'bit',
#  'elm',
#  'character',
#  'dy',
#  'sense',
#  'every',
#  'neighborhood',
#  'since',
#  'kind',
#  'see',
#  'rarely',
#  'attempt',
#  'dead',
#  'main',
#  'obviously',
#  'little',
#  'offering',
#  'folk',
#  'disappearance',
#  'entire',
#  'took',
#  'lost',
#  'beauty',
#  'horror',
#  'neat',
#  'edge',
#  'unravel',
#  'packaged',
#  '9/10',
#  'exact',
#  'chopped',
#  'teen',
#  'redundant',
#  'audience',
#  'explained',
#  'bottom',
#  'ending',
#  'write',
#  '2',
#  'people',
#  'studio',
#  'minute',
#  'big',
#  'guess',
#  'going',
#  'coming',
#  'even',
#  'well',
#  'scene',
#  'confusing',
#  'mold',
#  'get',
#  'others',
#  'snag',
#  'touch',
#  'critique',
#  'witch',
#  'type',
#  'given',
#  'someone',
#  'like',
#  'cool',
#  'biggest',
#  'world',
#  'part',
#  'actually',
#  'executed',
#  'know',
#  'explanation',
#  'playing',
#  'shelf',
#  'nightmare',
#  'bad',
#  'wrapped',
#  "'s",
#  'sagemiller',
#  'start',
#  'video',
#  'one',
#  '4/10',
#  'way',
#  'make',
#  'harder',
#  'good',
#  'completely',
#  'half-way',
#  'point',
#  'sure',
#  'plain',
#  'might',
#  'movie',
#  ',',
#  'entertaining',
#  'mean',
#  'password',
#  'jumbled',
#  'film',
#  'taken',
#  'vision',
#  'insight',
#  'guy',
#  'american',
#  'strangeness',
#  'hide',
#  'problem',
#  'different',
#  'review',
#  'secret',
#  'came',
#  'drink',
#  'highway',
#  'hot',
#  'craziness',
#  'enter',
#  '10/10',
#  'feeling',
#  'ton',
#  'decent',
#  'find',
#  'strange',
#  'meantime',
#  'figured',
#  'actor',
#  '3',
#  'away',
#  'girlfriend',
#  'blair',
#  'present',
#  'drive',
#  'whatever',
#  'music',
#  'line',
#  'ever',
#  ')',
#  'lazy',
#  'head',
#  'memento',
#  'normal',
#  'although',
#  'engaging',
#  '!',
#  'assuming',
#  'couple',
#  'flick',
#  'simply',
#  'melissa',
#  'making',
#  'correctly',
#  'trying',
#  'despite',
#  'genre',
#  'crow',
#  '8/10',
#  'turning',
#  'ago',
#  'feel',
#  'weird',
#  'look',
#  'oh',
#  'joblo',
#  ':',
#  'sitting',
#  '-',
#  'concept',
#  'suit',
#  'generation',
#  'pretty',
#  'show',
#  'dig',
#  'okay',
#  '7/10',
#  'give',
#  'mess',
#  '?',
#  'dream',
#  'member',
#  'skip',
#  'overall',
#  'break',
#  "n't",
#  'echo',
#  'seem',
#  'entertain',
#  "'ve",
#  'runtime',
#  'production',
#  'understanding',
#  'year',
#  'apparition',
#  'continues',
#  'chasing',
#  'wes',
#  'kudos',
#  'idea',
#  'stick',
#  'final',
#  'seemed',
#  'kick',
#  'come',
#  'work',
#  'drunkenly',
#  'stan',
#  'occasional',
#  'acting',
#  'middle',
#  'body',
#  'real',
#  'sunken',
#  'bringing',
#  'h20',
#  'stumbling',
#  'russian',
#  'mir',
#  'around',
#  'y2k',
#  'donald',
#  'shot',
#  'bastard',
#  'picking',
#  'within',
#  'tech',
#  'hey',
#  'design',
#  'happy',
#  'much',
#  'flashy',
#  'baldwin',
#  'sequence',
#  "'re",
#  'power',
#  'brother',
#  'empty',
#  'origin',
#  'quick',
#  'let',
#  'regarding',
#  'halloween',
#  'starring',
#  'virus',
#  'substance',
#  'average',
#  'cgi',
#  'winston',
#  'ship',
#  'lee',
#  'course',
#  'action',
#  'tugboat',
#  'hit',
#  'wasted',
#  'damn',
#  'curtis',
#  'william',
#  'story',
#  'across',
#  'time',
#  'star',
#  'otherwise',
#  'gore',
#  'flash',
#  'sutherland',
#  'nowhere',
#  'jamie',
#  'likely',
#  'robot',
#  'another',
#  'crew',
#  'bug',
#  'turn',
#  'deserted',
#  'brain',
#  'pink',
#  'certainly',
#  'juvenile',
#  'fifteen',
#  'rash',
#  'blowing',
#  'squad',
#  'unfortunately',
#  'escape',
#  'clear',
#  'appears',
#  'epps',
#  'play',
#  'clich',
#  'deliver',
#  'indication',
#  'extremely',
#  'avoid',
#  'basing',
#  'cast',
#  'transfer',
#  'complete',
#  'stuff',
#  'cop',
#  'questionable',
#  'hip',
#  'considers',
#  'span',
#  'teenage',
#  'wooden',
#  'half',
#  'car',
#  'becomes',
#  'r',
#  'screen',
#  'described',
#  'ad',
#  'worth',
#  'predictable',
#  'literally',
#  'wo',
#  'outfit',
#  'towards',
#  'apparent',
#  'based',
#  'enough',
#  'hard',
#  'rating',
#  'hour-long',
#  'everything',
#  'however',
#  'content',
#  'missing',
#  'dollar',
#  'instead',
#  'number',
#  'fact',
#  'older',
#  'best',
#  'giovanni',
#  'especially',
#  'care',
#  'omar',
#  'stolen',
#  'reformed',
#  'mod',
#  'tale',
#  'dane',
#  'element',
#  'suspicion',
#  'nice',
#  'recycled',
#  'progress',
#  'already',
#  'cost',
#  'seeing',
#  'dialogue',
#  'three',
#  'spoon-fed',
#  'single',
#  'thankful',
#  'immediately',
#  'hair',
#  'seen',
#  'occupying',
#  'jeopardy',
#  'six',
#  'stretched',
#  'slick',
#  'finger',
#  'remembers',
#  'cross',
#  'police',
#  'cash',
#  'claire',
#  'telling',
#  'save',
#  'unscathed',
#  'employ',
#  'onto',
#  'resident',
#  'cut',
#  'bordering',
#  'information',
#  'hour',
#  'counted',
#  'name',
#  'nothing',
#  'hand',
#  'matter',
#  'spending',
#  'late',
#  '1960',
#  'checked',
#  'tell',
#  'sometimes',
#  'costume',
#  'crazy',
#  'first',
#  'viewer',
#  'invention',
#  'awful',
#  'memorable',
#  'cute',
#  'judging',
#  'clothes',
#  'watching',
#  'sound',
#  'ribisi',
#  'hero',
#  'wisdom',
#  'convoluted',
#  "'ll",
#  'written',
#  'evidence',
#  'looking',
#  'target',
#  'bored',
#  'apart',
#  'criminal',
#  'young',
#  'nobody',
#  'wrong',
#  'relatively',
#  'jaded',
#  'spectacular',
#  'ultimately',
#  'poorly',
#  'geared',
#  'quickly',
#  'soundtrack',
#  'man',
#  'undercover',
#  "'",
#  'television',
#  'justify',
#  'mindset',
#  'instantly',
#  'bronson',
#  'recent',
#  'promising',
#  'specific',
#  'fan',
#  'arrival',
#  'error',
#  '1997',
#  'challenger',
#  'revolves',
#  'two-headed',
#  'must',
#  'warner',
#  'magical',
#  'hands-down',
#  'palate',
#  '--',
#  'rank',
#  'saturday',
#  'jane',
#  'hydra',
#  'recall',
#  'personality',
#  'arthur',
#  'child',
#  'keeping',
#  'colorful',
#  'seymour',
#  'lack',
#  'rickles',
#  'singer',
#  'loses',
#  'sign',
#  'century',
#  'showmanship',
#  'rest',
#  'sexist',
#  'case',
#  'reason',
#  'comedy',
#  'cloying',
#  'pocahontas',
#  'crown',
#  'forest',
#  'awfully',
#  'shtick',
#  'free-spirited',
#  'sharing',
#  'animation',
#  'climb',
#  'king',
#  'table',
#  'something',
#  '20th',
#  'run-in',
#  'follow',
#  'footage',
#  'compare',
#  'accidentally',
#  'line-up',
#  'eric',
#  'angry',
#  'nearly',
#  'probably',
#  'sword',
#  'belated',
#  'kingdom',
#  'high',
#  'thrilled',
#  'hunky',
#  'voiced',
#  'herc',
#  'strain',
#  'feature-length',
#  'garrett',
#  'clout',
#  'fox',
#  'able',
#  'remotely',
#  'providing',
#  "'d",
#  'forgettable',
#  'magic',
#  'paired',
#  'worried',
#  'anastasia',
#  'mediocre',
#  'footstep',
#  'computerized',
#  'end',
#  'nicely',
#  'warlord',
#  'throne',
#  'camelot',
#  'pinchot',
#  'mouse',
#  'flawed',
#  'enthusiastic',
#  'morning',
#  'differentiates',
#  'celine',
#  'ogre',
#  'last',
#  'dragon',
#  'stink',
#  'father',
#  'round',
#  'none',
#  'oldman',
#  'learn',
#  'song',
#  'aside',
#  'knight',
#  'beat',
#  'fighter',
#  'essential',
#  'expected',
#  'white',
#  'disney',
#  'adult',
#  'chance',
#  "'m",
#  'though',
#  'idle',
#  'grievous',
#  'cartoon',
#  'contest',
#  'elwes',
#  'musical',
#  'carey',
#  'evil',
#  'pulse',
#  'dull',
#  'side',
#  'voice',
#  'pure',
#  'realized',
#  'tgif',
#  'gary',
#  'empire',
#  'long',
#  'interesting',
#  'steal',
#  'race',
#  'piece',
#  'battle',
#  'talent',
#  'adventure',
#  'help',
#  'hercules',
#  'score',
#  'fall',
#  'moment',
#  'dangerous',
#  'medieval',
#  'prove',
#  'daughter',
#  'lively',
#  'urkel',
#  'tie',
#  'least',
#  'quest',
#  'arguing',
#  'excalibur',
#  'subpar',
#  'win',
#  'loss',
#  'blind',
#  'bros',
#  'stalker',
#  'produce',
#  'found',
#  'adequate',
#  '1990s',
#  'comment',
#  'collect',
#  'try',
#  'quite',
#  'presence',
#  'endless',
#  'strip',
#  'picture',
#  'proliferation',
#  'become',
#  'receives',
#  'invariably',
#  'front',
#  'potentially',
#  'implied',
#  'proceed',
#  'mostly',
#  'inevitable',
#  'love',
#  'direct-to-video',
#  'heroine',
#  'instance',
#  'shower',
#  'psycho',
#  'derivative',
#  'toward',
#  'late-night',
#  'stalk',
#  'allowing',
#  'place',
#  'brings',
#  'kill',
#  'episode',
#  'slightly',
#  'played',
#  'all-time',
#  'cliche',
#  'disbelief',
#  'stalked',
#  'serve',
#  'unsuccessfully',
#  'left',
#  'inside',
#  'ex-husband',
#  'gleason',
#  'mother',
#  'ponders',
#  'event',
#  'open',
#  'provide',
#  'parked',
#  'underwood',
#  'independent',
#  'several',
#  'meant',
#  'rejected',
#  'brooke',
#  'typically',
#  'equally',
#  'somewhat',
#  'obvious',
#  'demand',
#  'jay',
#  'doomed',
#  'plan',
#  'men',
#  'suspense',
#  'daylight',
#  'door',
#  'opening',
#  'fledgling',
#  'together',
#  'murder',
#  'offensive',
#  'desperate',
#  'answer',
#  'living',
#  'exception',
#  'gain',
#  'never',
#  "d'abo",
#  'proceeds',
#  'synopsis',
#  'excuse',
#  'include',
#  'require',
#  'ex-lover',
#  'mood',
#  'seemingly',
#  'daniel',
#  'entry',
#  'home',
#  'question',
#  'string',
#  'attempting',
#  'undergoing',
#  'ex-wife',
#  'manages',
#  'example',
#  'unstable',
#  'ditzy',
#  'called',
#  'return',
#  'bar',
#  'else',
#  'ob',
#  'intelligence',
#  'favor',
#  'close',
#  'shown',
#  'cable',
#  'special',
#  'waver',
#  'showdown',
#  'implicitly',
#  'many',
#  'industry',
#  'somehow',
#  'begin',
#  'norm',
#  'cause',
#  'strong',
#  'enters',
#  'inexpensive',
#  'watched',
#  'rather',
#  'conclusion',
#  'melodrama',
#  'validity',
#  'overdoes',
#  'required',
#  'contrary',
#  'highly',
#  'thriller',
#  'vehicle',
#  'set',
#  'respect',
#  'uniformly',
#  'suspension',
#  'wanders',
#  'daryl',
#  'effect',
#  'victim',
#  'elaborate',
#  'yet',
#  'bond',
#  'chick',
#  'house',
#  'anything',
#  'frequent',
#  'interspersed',
#  'due',
#  'state',
#  'incredible',
#  ';',
#  'affair',
#  'boring',
#  'stake',
#  'mentally',
#  'leave',
#  'credit',
#  'whole',
#  'turkey',
#  'brief',
#  'title',
#  'word',
#  'dust',
#  'boy',
#  'pet',
#  'fatal',
#  'woo',
#  'ensure',
#  'follows',
#  'murdered',
#  'either',
#  'decides',
#  'take',
#  'stable',
#  'nudity',
#  'psychotherapy',
#  'midnight',
#  'lead',
#  'contrived',
#  'cat',
#  'woman',
#  'may',
#  'pas',
#  'oblivious',
#  'theatrical',
#  'spout',
#  'category',
#  'survives',
#  'creepy',
#  'viewed',
#  'rated',
#  'narrator',
#  'snapshot',
#  'use',
#  'right',
#  'danger',
#  'darkness',
#  'novel',
#  'release',
#  'sucker',
#  'moderately',
#  'alien',
#  'savage',
#  'essentially',
#  'tone',
#  'except',
#  'manner',
#  'following',
#  'capsule',
#  'homage',
#  'panned',
#  'taking',
#  'supposedly',
#  'automatic',
#  'rushing',
#  'wife',
#  'desolation',
#  'powerful',
#  'terror',
#  'fit',
#  'decapitation',
#  'filmed',
#  'rundown',
#  'changed',
#  'imagination',
#  '-4',
#  'walk',
#  'advance',
#  'sue',
#  'train',
#  'stretch',
#  '4',
#  'basic',
#  'belief',
#  'classic',
#  'tacky',
#  'beyond',
#  '10',
#  'facing',
#  '13',
#  'scary',
#  'control',
#  'weapon',
#  'human',
#  'yellow',
#  'full',
#  'easier',
#  'expect',
#  'rate',
#  'wilson',
#  'mining',
#  'previous',
#  'female',
#  'entirely',
#  'position',
#  'told',
#  'mar',
#  '0',
#  'reviewer',
#  'carpenter',
#  'face',
#  'sudden',
#  'custody',
#  'liked',
#  'accused',
#  'precinct',
#  'buildup',
#  'lot',
#  'twice',
#  'view',
#  'surface',
#  'red',
#  'great',
#  'ghost',
#  'surprising',
#  'unimpressive',
#  'jump',
#  'minor',
#  'admittedly',
#  'yes',
#  'advanced',
#  '2176',
#  'colony',
#  'gravity',
#  'ten',
#  'replaced',
#  'hoodlum',
#  'building',
#  'assault',
#  'thinking',
#  'science',
#  'wannabe',
#  'planet',
#  'williams',
#  'expert',
#  'heavy',
#  'gear',
#  'murderer',
#  'surprisingly',
#  'le',
#  'nature',
#  'fiction',
#  'mission',
#  '175',
#  'kiss',
#  'almost',
#  'standard',
#  'fighting',
#  'made',
#  'ground',
#  'martian',
#  'haunted',
#  'drawn',
#  'common',
#  'menace',
#  'managed',
#  'fight',
#  'anybody',
#  'digital',
#  'bunch',
#  'sadly',
#  '9',
#  'happening',
#  'night',
#  'without',
#  'black',
#  'addition',
#  'breathing',
#  'lapse',
#  'increased',
#  'writer',
#  'reprises',
#  ...]

# %%
# Just how many words did we remove from our vocabulary?

len(more_than_once), len(tdf_counts.keys())
# Out:
# (22567, 41950)

# %%
# Now we can go back through our movie reviews and remove
# any words that were not included in 'more_than_once'

# As mentioned above, it is much more efficient to perform that task using a 'set'

more_than_once_set = set(more_than_once)

# %%
negative_min_df = [[word for word in review if word in more_than_once_set] for review in negative_sets]
positive_min_df = [[word for word in review if word in more_than_once_set] for review in positive_sets]

# %%
# Inspect
negative_min_df[0]
# Out:
# ['somewhere',
#  'applaud',
#  'watch',
#  '(',
#  'decided',
#  'clue',
#  'fantasy',
#  'slasher',
#  'life',
#  'really',
#  'kid',
#  'director',
#  'throughout',
#  'apparently',
#  'hold',
#  'terribly',
#  'always',
#  'also',
#  'stir',
#  'street',
#  'church',
#  'party',
#  '&',
#  'downshift',
#  'got',
#  'unraveling',
#  'generally',
#  'thing',
#  'new',
#  'u',
#  'plot',
#  'arrow',
#  'showing',
#  'seems',
#  'accident',
#  'mind',
#  '.',
#  'giving',
#  'bentley',
#  'deal',
#  '``',
#  'five',
#  'need',
#  'back',
#  'thrilling',
#  'go',
#  'sad',
#  'running',
#  'excites',
#  '20',
#  'happen',
#  'chase',
#  'want',
#  'sorta',
#  'personally',
#  'fed',
#  'two',
#  'still',
#  'would',
#  'salvation',
#  'package',
#  'bit',
#  'elm',
#  'character',
#  'dy',
#  'sense',
#  'every',
#  'neighborhood',
#  'since',
#  'kind',
#  'see',
#  'rarely',
#  'attempt',
#  'dead',
#  'main',
#  'obviously',
#  'little',
#  'offering',
#  'folk',
#  'disappearance',
#  'entire',
#  'took',
#  'lost',
#  'beauty',
#  'horror',
#  'neat',
#  'edge',
#  'unravel',
#  'packaged',
#  '9/10',
#  'exact',
#  'chopped',
#  'teen',
#  'redundant',
#  'audience',
#  'explained',
#  'bottom',
#  'ending',
#  'write',
#  '2',
#  'people',
#  'studio',
#  'minute',
#  'big',
#  'guess',
#  'going',
#  'coming',
#  'even',
#  'well',
#  'scene',
#  'confusing',
#  'mold',
#  'get',
#  'others',
#  'snag',
#  'touch',
#  'critique',
#  'witch',
#  'type',
#  'given',
#  'someone',
#  'like',
#  'cool',
#  'biggest',
#  'world',
#  'part',
#  'actually',
#  'executed',
#  'know',
#  'explanation',
#  'playing',
#  'shelf',
#  'nightmare',
#  'bad',
#  'wrapped',
#  "'s",
#  'sagemiller',
#  'start',
#  'video',
#  'one',
#  '4/10',
#  'way',
#  'make',
#  'harder',
#  'good',
#  'completely',
#  'half-way',
#  'point',
#  'sure',
#  'plain',
#  'might',
#  'movie',
#  ',',
#  'entertaining',
#  'mean',
#  'password',
#  'jumbled',
#  'film',
#  'taken',
#  'vision',
#  'insight',
#  'guy',
#  'american',
#  'strangeness',
#  'hide',
#  'problem',
#  'different',
#  'review',
#  'secret',
#  'came',
#  'drink',
#  'highway',
#  'hot',
#  'craziness',
#  'enter',
#  '10/10',
#  'feeling',
#  'ton',
#  'decent',
#  'find',
#  'strange',
#  'meantime',
#  'figured',
#  'actor',
#  '3',
#  'away',
#  'girlfriend',
#  'blair',
#  'present',
#  'drive',
#  'whatever',
#  'music',
#  'line',
#  'ever',
#  ')',
#  'lazy',
#  'head',
#  'memento',
#  'normal',
#  'although',
#  'engaging',
#  '!',
#  'assuming',
#  'couple',
#  'flick',
#  'simply',
#  'melissa',
#  'making',
#  'correctly',
#  'trying',
#  'despite',
#  'genre',
#  'crow',
#  '8/10',
#  'turning',
#  'ago',
#  'feel',
#  'weird',
#  'look',
#  'oh',
#  'joblo',
#  ':',
#  'sitting',
#  '-',
#  'concept',
#  'suit',
#  'generation',
#  'pretty',
#  'show',
#  'dig',
#  'okay',
#  '7/10',
#  'give',
#  'mess',
#  '?',
#  'dream',
#  'member',
#  'skip',
#  'overall',
#  'break',
#  "n't",
#  'echo',
#  'seem',
#  'entertain',
#  "'ve",
#  'runtime',
#  'production',
#  'understanding',
#  'year',
#  'apparition',
#  'continues',
#  'chasing',
#  'wes',
#  'kudos',
#  'idea',
#  'stick',
#  'final',
#  'seemed']

# %%
## EXERCISE.  Get a list of the 500 words with the highest document frequencies.

## CHALLENGE: Only words should be contained in the list.

## CHALLENGE: You can remove low-frequency words based on document frequency.
##            Another popular method is to retain only high-frequency
##            words based on the raw number of times they appear in the corpus
##            (i.e. the sum of their counts in all texts).

##            Use this method to find the 500 most common terms in the movie corpus.
##            Does this match with the list in the previous exercise?

# %% [markdown]
# # 4. Classification

# %% [markdown]
# ### Featurise
#
# For humans, reading a string of text is a relatively easy task, but for the computer to learn about language, text has to be represented in very particular ways. We refer to this as <i>featurisation</i>: the transformation of a text into a quantitative feature set.
#
# In order for the NLTK classifier to work, we have to represent each text as a set of True/False values: Is a given word from our high-frequency vocabulary present in this review? More specifically, these values will be contained in a <i>dictionary</i>, where each key is a vocabulary word and its value is whether or not it is present. In fact, we need only to include terms that are present, so all of our values will be True.
#
# Once we have processed each text according to this rubric, we will then attach a label for the text's category ('reviewed'/'random). The classifier will use this to identify which features are associated with each.

# %%
# Let's revisit some earlier tokens

unladen_tokens = ['high','air-speed','velocity']

# %%
# In order to represent our tokens to the classifier, we need to
# associate them with a 'True' value in a dictionary

# Sure looks like a list comprehension!

{token:True for token in unladen_tokens}

# %%
# In general, we are not limited to True/False values to our dictionary entries
# For example:

{token:len(token) for token in unladen_tokens}

# %%
# Turn our reviews into dictionaries that indicate whether a word is present

negative_featurized = [{word:True for word in review} for review in negative_min_df]
positive_featurized = [{word:True for word in review} for review in positive_min_df]

# %%
# Inspect first review

negative_featurized[0]

# %%
# Attach a label to each review
negative_tagged = [(review,'negative') for review in negative_featurized]
positive_tagged = [(review,'positive') for review in positive_featurized]

# %%
# Inspect
negative_tagged[0]

# %%
# Combine these lists of featurized, tagged reviews
all_tagged = negative_tagged + positive_tagged

# %%
## NOTE. We'll spend more time with dictionaries in the next module, so let's hand wave
##       it as a formatting step for now and move on to classification!

# %% [markdown]
# ### Classification
#
# We have selected an algorithm that specifically relies on <a href="https://en.wikipedia.org/wiki/Bayes%27_theorem">Bayes' Theorem</a> to model relationships between textual features and categories in our corpus of movie reviews. (See link for more information about the method and its assumptions.)
#
# Two ways that we learn about the model are its feature weights and predictions on new texts. The algorithm can explicity report to us which direction each word leans category-wise and how strongly. Based on those weights, it makes further predictions about the valences previously unseen movie reviews.

# %%
# Train the classifier and assign it to a variable

from nltk import NaiveBayesClassifier

classifier = NaiveBayesClassifier.train(all_tagged)

# %%
# Report feature information, this is a list of which words are most related to either positive or negative reviews!
classifier.show_most_informative_features(10)

# %%
# Roger Ebert's reviews of a couple family films

# "This movie made my heart glad. It is filled with innocence, hope, and good cheer."
#    -Roger Ebert, on ET

positive_ET = {'best': True, 'baffled': True, 'space': True, 'relationship': True, 'people': True, 'little': True,\
            'friendship': True, 'love': True, 'story': True, 'becomes': True,'hear': True, 'outer': True,\
            'boy': True, 'friend': True, 'tells': True, 'creature': True, 'described': True}

# "I hated this movie. Hated, hated, hated, hated, hated this movie. Hated it.
#  Hated every simpering stupid vacant audience-insulting moment of it."
#     -Roger Ebert, on "North"

negative_north = {'simpering': True, 'belief': True, 'every': True, 'thought': True, 'implied': True,\
                  'entertained': True, 'insulting': True, 'vacant': True, 'sensibility': True, 'stupid': True,\
                  'insult': True, 'audience': True, 'anyone': True, 'movie': True, 'hated': True, 'moment': True}

# %%
# What does the classifier think?

classifier.classify(positive_ET)

# %%
classifier.classify(negative_north)

# %%
# Predictions for a list of reviews

review_list = [positive_ET, negative_north]
classifier.classify_many(review_list)

# %%
# Although our classification is binary, Bayes theorem assigns
# a probability of membership in either category

# Just how confident is our classifier of its predictions?

classifier.prob_classify(positive_ET).prob('positive')

# %%
classifier.prob_classify(negative_north).prob('negative')

# %%
## EXERCISE. Below there are the locations of two movie reviews that the clasifier has not yet seen.
##           Use the classifier to predict whether they are positive or negative.

ebert_neg_location = 'movie_reviews/ebert/Roger Ebert - Battlefield Earth (negative review).txt'
ebert_pos_location = 'movie_reviews/ebert/Roger Ebert - Toy Story (positive review).txt'

## Q.  What kinds of patterns do you notice among the 'most informative features'
##     in the movie review corpus. Where are critics focusing their attention?
##     Try looking at the top several hundred most informative words.

# %% [markdown]
# ## Extra: Cross-Validation
#
# Just how good is our classifier? We can evaluate it by randomly selecting reviews from each category and setting them aside before training. We then see how well the classifier predicts their (known) categories.
#
# Remember that if the classifier is trying to predict membership for just two categories, we would expect it to be correct about 50% of the time based on random chance. As a rule of thumb, if this kind of classifier has 65% accuracy or better under cross-validation, it has often identified a meaningful pattern.

# %%
# Randomise our list of movie reviews (in place)

# !pip install numpy
import numpy
numpy.random.shuffle(all_tagged)

# %%
# We'll train our classifier on the first 90% of reviews
# and validate using the last 10%

training_set = all_tagged[:-72]
validation_set = all_tagged[-72:]

# %%
# Train, validate, show accuracy

classifier = nltk.NaiveBayesClassifier.train(training_set)
nltk.classify.accuracy(classifier, validation_set)

# %%
## CHALLENGE. In fact, this is not the best implementation of cross-validation, since we used
##            the entire corpus to identify words that appear more than once. In effect, we have
##            passed information from our validation set into the classifier we wish to test.

##            Repeat the processing of the corpus based only on the training set and use this to
##            make predictions about the validation set. How much does the classifier's accuracy change? Why?
